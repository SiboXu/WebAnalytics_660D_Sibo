# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import pandas as pd
import bs4
import numpy as np

# %% [markdown]
# ## Question 1
# - Which team had the most homeruns in the regular season of 2015? Print the full team name.

# %%
# Using FireFox driver
driver = webdriver.Firefox(executable_path='./geckodriver')

# %%
driver.close()

# %%
driver.get('http://www.mlb.com')

# %%
stats_header_bar = driver.find_element_by_class_name('megamenu-navbar-overflow__menu-item-link--stats')

# %%
stats_header_bar.click()

# %%
# click again, sometimes it doesn't work so will have to double click.
stats_header_bar.click()

# %%
#stats_line_items = stats_header_bar.find_element_by_tag_name('li')
#stats_line_items

# %%
# get the season 2015, id:sp_hitting_season
season_element = driver.find_element_by_id('sp_hitting_season')

# %%
season_element.click()

# %%
season_select = Select(season_element)
season_select.select_by_value('2015')

# %%
# get the regular season id:sp_hitting_game_type
gametype_element = driver.find_element_by_id('sp_hitting_game_type')

# %%
gametype_element.click()

# %%
gametype_select = Select(gametype_element)
gametype_select.select_by_value("'R'")

# %%
# get team button
content_wrap_stats = driver.find_element_by_id('contentWrap')

# %%
# click team button
team_bar = content_wrap_stats.find_element_by_id('st_parent')
team_bar.click()

# %%
# get the data of all team and sort by the HR(home run)
hr_bottom = driver.find_element_by_tag_name('thead')
hr = hr_bottom.find_element_by_class_name('dg-hr')
hr.click()
#ActionChains(driver).move_to_element(hr_bottom).click()

# %%
# get the header
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
soup_tr = soup.thead.tr
team_header = [t.text.replace('▼','') for t in soup_tr.findAll('th')]
#team_header.remove('')
# len(team_header)

# %%
# get the stats for each team
soup_tbody = soup.tbody
team_stats = []
#for t in soup_tbody:
    #print (t.tr)
soup_tbody_tr = soup_tbody.findAll('tr')
for tr in soup_tbody_tr:
    #print(tr)
    team_detail = [t.text for t in tr.findAll('td')]
    #print(team_detail)
    team_stats.append(team_detail)
#print (soup_tbody[0].prettify())
#team_stats

# %%
# print the top1 team
df_hr = pd.DataFrame(data= team_stats, columns=team_header)
top1_hr = pd.DataFrame(df_hr[['Team','HR']].iloc[0])
top1_hr[0][0]
print (top1_hr[0][0])
df_hr
# Out:
# Toronto Blue Jays
#     RK                   Team      League    G    AB    R     H   2B  3B  \
# 0    1      Toronto Blue Jays  tor     AL  162  5509  891  1480  308  17
# 1    2         Houston Astros  hou     AL  162  5459  729  1363  278  26
# 2    3      Baltimore Orioles  bal     AL  162  5485  713  1370  246  20
# 3    4       New York Yankees  nyy     AL  162  5567  764  1397  272  19
# 4    5       Seattle Mariners  sea     AL  162  5544  656  1379  262  22
# 5    6    Los Angeles Dodgers   la     NL  162  5385  667  1346  263  26
# 6    7       Colorado Rockies  col     NL  162  5572  737  1479  274  49
# 7    8          New York Mets  nym     NL  162  5527  683  1351  295  17
# 8    8   Washington Nationals  was     NL  162  5428  703  1363  265  13
# 9   10     Los Angeles Angels  ana     AL  162  5417  661  1331  243  21
# 10  11          Texas Rangers  tex     AL  162  5511  751  1419  279  32
# 11  12           Chicago Cubs  chc     NL  162  5491  689  1341  272  30
# 12  13        Cincinnati Reds  cin     NL  162  5571  640  1382  257  27
# 13  13         Tampa Bay Rays   tb     AL  162  5485  644  1383  278  32
# 14  15         Boston Red Sox  bos     AL  162  5640  748  1495  294  33
# 15  16        Minnesota Twins  min     AL  162  5467  696  1349  277  44
# 16  17   Arizona Diamondbacks  ari     NL  162  5649  720  1494  289  48
# 17  18         Detroit Tigers  det     AL  161  5605  689  1515  289  49
# 18  19       San Diego Padres   sd     NL  162  5457  650  1324  260  36
# 19  20      Oakland Athletics  oak     AL  162  5600  694  1405  277  46
# 20  21      Milwaukee Brewers  mil     NL  162  5480  655  1378  274  34
# 21  22      Cleveland Indians  cle     AL  161  5439  669  1395  303  29
# 22  23     Pittsburgh Pirates  pit     NL  162  5631  697  1462  292  27
# 23  24     Kansas City Royals   kc     AL  162  5575  724  1497  300  42
# 24  25    St. Louis Cardinals  stl     NL  162  5484  647  1386  288  39
# 25  26      Chicago White Sox  cws     AL  162  5533  622  1381  260  27
# 26  26   San Francisco Giants   sf     NL  162  5565  696  1486  288  39
# 27  28  Philadelphia Phillies  phi     NL  162  5529  626  1374  272  37
# 28  29          Miami Marlins  mia     NL  162  5463  613  1420  236  40
# 29  30         Atlanta Braves  atl     NL  162  5420  573  1361  251  18
#
#     ...  SAC  SF    TB  XBH  GDP    GO    AO GO_AO     NP    PA
# 0   ...   36  62  2518  557  140  1724  1395  1.24  24051  6231
# 1   ...   28  43  2383  534  102  1439  1438  1.00  23543  6073
# 2   ...   20  32  2307  483  127  1561  1402  1.11  22911  6007
# 3   ...   24  54  2343  503  105  1558  1568  0.99  24523  6268
# 4   ...   38  35  2279  482  123  1607  1418  1.13  23814  6131
# 5   ...   49  30  2222  476  135  1630  1365  1.19  23602  6090
# 6   ...   44  34  2409  509  114  1628  1374  1.18  22661  6071
# 7   ...   29  32  2211  489  130  1540  1537  1.00  23931  6145
# 8   ...   55  51  2185  455  129  1704  1252  1.36  23247  6117
# 9   ...   37  40  2144  440  116  1676  1453  1.15  22727  5990
# 10  ...   43  54  2278  483   99  1648  1407  1.17  23738  6187
# 11  ...   32  35  2186  473  101  1462  1338  1.09  24646  6200
# 12  ...   47  40  2194  451  112  1640  1493  1.10  23533  6196
# 13  ...   19  47  2226  477  121  1510  1469  1.03  23210  6071
# 14  ...   30  42  2338  488  127  1756  1440  1.22  24709  6237
# 15  ...   30  41  2182  477  133  1634  1424  1.15  23100  6017
# 16  ...   46  57  2341  491  134  1759  1321  1.33  23332  6276
# 17  ...   23  35  2355  489  152  1584  1460  1.08  23702  6159
# 18  ...   52  42  2100  444  108  1597  1411  1.13  23200  6019
# 19  ...   14  38  2212  469  124  1704  1548  1.10  23808  6171
# 20  ...   55  34  2155  453  130  1730  1292  1.34  22558  6024
# 21  ...   47  50  2179  473  134  1675  1443  1.16  23795  6109
# 22  ...   63  41  2228  459  115  1739  1327  1.31  23889  6285
# 23  ...   34  47  2298  481  133  1759  1560  1.13  22705  6116
# 24  ...   39  42  2163  464  128  1677  1363  1.23  23494  6139
# 25  ...   30  37  2103  423  125  1807  1306  1.38  23140  6070
# 26  ...   45  37  2260  463  142  1830  1314  1.39  23191  6153
# 27  ...   53  29  2110  439  119  1693  1389  1.22  22644  6053
# 28  ...   71  40  2096  396  133  1921  1216  1.58  22254  5988
# 29  ...   67  31  1948  369  148  1902  1296  1.47  22644  6034
#
# [30 rows x 32 columns]

# %%
df_hr.to_csv('Question_1.csv', sep=',',index_label=True)

# %%
###### Q1. get answer from the csv stored #####

with open ('Question_1.csv', 'r') as q1:
    top1_hr = pd.read_csv(q1, sep= ',' )
        
top1_team_name = top1_hr.iloc[0]['Team']
print ('The answer for Q1:')
print ('The team had the most homeruns in the regular season of 2015 is', top1_team_name,'.')
# Out:
# The answer for Q1:
# The team had the most homeruns in the regular season of 2015 is Toronto Blue Jays .

# %%
txt = ['Toronto Blue Jays']
answer_1 = pd.DataFrame(txt, columns=['Team'])
answer_1.to_csv('Answer_1.csv', sep = ',')

# %% [markdown]
# ## Question 2
# - Which league (AL or NL) had the greatest average number of homeruns…
#   1. in the regular season of 2015? Please give the league name and the average number of homeruns.
#   2. in the regular season of 2015 in the first inning? Please give the league name and the average number of homeruns.

# %%
### reade data to answer sub-question 1 of Question 2 #####
with open ('Question_1.csv', 'r') as q2_1:
    df_hr_q2= pd.read_csv(q2_1, sep=',')

# %%
al_df = df_hr_q2.loc[lambda df_hr: df_hr.League =='AL', :]
nl_df = df_hr_q2.loc[lambda df_hr: df_hr.League =='NL', :]
nl_mean = np.mean(nl_df['HR'].apply(int))
#print ('The average number of homeruns fo the NL:', nl_mean)
al_mean = np.mean(al_df['HR'].apply(int))
#print ('The average number of homeruns fo the AL:', al_mean)
print ('The answer for question 2.1:')

if nl_mean > al_mean:
    print ('NL had the greatest average number of homeruns:', nl_mean)
else:
    print ('AL had the greatest average number of homeruns:' , al_mean)
# Out:
# The answer for question 2.1:
# AL had the greatest average number of homeruns: 175.6

# %%
### scrape data to answer sub-question 2 of Question 2 #####

# get the data for the first inning, id:st_hitting_hitting_splits
split_element = driver.find_element_by_id('st_hitting_hitting_splits')
split_element.click()

# %%
split_select = Select(split_element)
# value for the first inning is 'i01'
split_select.select_by_value("i01")

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
soup_thead_tr = soup.thead.tr
team_header_1stin = [t.text.replace('▼','') for t in soup_thead_tr.findAll('th')]

# %%
soup_tbody = soup.tbody
team_stats_1stin = []
#for t in soup_tbody:
    #print (t.tr)
soup_tbody_tr = soup_tbody.findAll('tr')
for tr in soup_tbody_tr:
    #print(tr)
    team_detail = [t.text for t in tr.findAll('td')]
    #print(team_detail)
    team_stats_1stin.append(team_detail)
    
df_1stin = pd.DataFrame(data= team_stats_1stin, columns=team_header_1stin)

########
####save the data for question2.2
df_1stin.to_csv('Question_2_2.csv', sep=',',index_label='INDEX')

# %%
####### open the saved Question_2_2.csv to answer the sub-question 2 of Question 2
with open ('Question_2_2.csv', 'r') as q22:
    df_1stin= pd.read_csv(q22, sep=',')

al_df_1st = df_1stin.loc[lambda df_hr: df_hr.League =='AL', :]
nl_df_1st = df_1stin.loc[lambda df_hr: df_hr.League =='NL', :]
nl_mean = np.mean(nl_df_1st['HR'].apply(int))
#print (nl_mean)
al_mean = np.mean(al_df_1st['HR'].apply(int))
#print (al_mean)
print ('The answer for question 2.2:')
if nl_mean > al_mean:
    print ('NL had the greatest average number of homeruns in the first inning:', nl_mean)
else:
    print ('AL had the greatest average number of homeruns in the first inning:' , al_mean)
# Out:
# The answer for question 2.2:
# AL had the greatest average number of homeruns in the first inning: 23.666666666666668

# %%
txt = [['AL', 175.6],['AL',23.666666666666668 ]]
answer_2 = pd.DataFrame(txt, columns=['League','AVG'])
answer_2
answer_2.to_csv('Answer_2.csv', sep = ',')

# %% [markdown]
# ## Question 3
# - What is the name of the player with the best overall batting average in the 2017 regular season that played for the New York Yankees, who
#    1. had at least 30 at bats? Please give his full name and position.
#    2. played in the outfield (RF, CF, LF)? Please give his full name and position.

# %%
# get the player lookup table

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'ff202b724b714dc3aa66aa292a78b964',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/mlb/stats/json/Players/NYY?%s" % params, "{body}", headers)
    response = conn.getresponse()
    nyy_players = response.read()
    # print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
import json
nyy = json.loads(nyy_players)
nyy
# Out:
# [{'BatHand': 'R',
#   'BirthCity': 'Grants Pass',
#   'BirthCountry': 'USA',
#   'BirthDate': '1992-08-21T00:00:00',
#   'BirthState': 'OR',
#   'College': None,
#   'DraftKingsName': 'Brandon Drury',
#   'DraftKingsPlayerID': 549169,
#   'FanDuelName': 'Brandon Drury',
#   'FanDuelPlayerID': 21172,
#   'FantasyAlarmPlayerID': 101214,
#   'FantasyDraftName': 'Brandon Drury',
#   'FantasyDraftPlayerID': 877752,
#   'FirstName': 'Brandon',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 29,
#   'LastName': 'Drury',
#   'MLBAMID': 592273,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000030.png',
#   'PlayerID': 10000030,
#   'Position': '3B',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12382,
#   'RotoworldPlayerID': 7038,
#   'Salary': None,
#   'SportRadarPlayerID': '37de17c5-5ff0-449e-b6a9-a936d1c9a78b',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 111165,
#   'StatsPlayerID': 549169,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 210,
#   'XmlTeamPlayerID': 8653,
#   'YahooName': 'Brandon Drury',
#   'YahooPlayerID': 9853},
#  {'BatHand': 'R',
#   'BirthCity': 'Marietta',
#   'BirthCountry': 'USA',
#   'BirthDate': '1987-09-27T00:00:00',
#   'BirthState': 'GA',
#   'College': 'Princeton',
#   'DraftKingsName': 'David Hale',
#   'DraftKingsPlayerID': 501206,
#   'FanDuelName': 'David Hale',
#   'FanDuelPlayerID': 38096,
#   'FantasyAlarmPlayerID': 100672,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'David',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 97,
#   'LastName': 'Hale',
#   'MLBAMID': 571735,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000054.png',
#   'PlayerID': 10000054,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 11044,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '99282b13-3e78-484e-a5af-f9e2c9dae886',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 104928,
#   'StatsPlayerID': 501206,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 210,
#   'XmlTeamPlayerID': 7296,
#   'YahooName': 'David Hale',
#   'YahooPlayerID': 9528},
#  {'BatHand': 'L',
#   'BirthCity': 'Lake Charles',
#   'BirthCountry': 'USA',
#   'BirthDate': '1990-05-09T00:00:00',
#   'BirthState': 'LA',
#   'College': 'McNeese State',
#   'DraftKingsName': 'Jace Peterson',
#   'DraftKingsPlayerID': 597803,
#   'FanDuelName': 'Jace Peterson',
#   'FanDuelPlayerID': 21573,
#   'FantasyAlarmPlayerID': 100998,
#   'FantasyDraftName': 'Jace Peterson',
#   'FantasyDraftPlayerID': 872270,
#   'FirstName': 'Jace',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 8,
#   'LastName': 'Peterson',
#   'MLBAMID': 607054,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000082.png',
#   'PlayerID': 10000082,
#   'Position': 'LF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12192,
#   'RotoworldPlayerID': 7013,
#   'Salary': None,
#   'SportRadarPlayerID': 'e43136cd-762f-4b3f-8595-4f07e83be3b2',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 113247,
#   'StatsPlayerID': 597803,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 215,
#   'XmlTeamPlayerID': 9129,
#   'YahooName': 'Jace Peterson',
#   'YahooPlayerID': 9618},
#  {'BatHand': 'L',
#   'BirthCity': 'St. Louis',
#   'BirthCountry': 'USA',
#   'BirthDate': '1984-11-02T00:00:00',
#   'BirthState': 'MO',
#   'College': 'Mount Olive',
#   'DraftKingsName': 'Tommy Layne',
#   'DraftKingsPlayerID': 392181,
#   'FanDuelName': 'Tommy Layne',
#   'FanDuelPlayerID': 23697,
#   'FantasyAlarmPlayerID': 100951,
#   'FantasyDraftName': 'Tommy Layne',
#   'FantasyDraftPlayerID': 885948,
#   'FirstName': 'Tommy',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 79,
#   'LastName': 'Layne',
#   'MLBAMID': 518927,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000149.png',
#   'PlayerID': 10000149,
#   'Position': 'P',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12694,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': 'da7a3e9a-ce7c-4b1a-a874-fb7c1774bcde',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 105741,
#   'StatsPlayerID': 392181,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 7828,
#   'YahooName': 'Tommy Layne',
#   'YahooPlayerID': 9270},
#  {'BatHand': 'R',
#   'BirthCity': 'Birmingham',
#   'BirthCountry': 'USA',
#   'BirthDate': '1985-04-09T00:00:00',
#   'BirthState': 'AL',
#   'College': 'Alabama',
#   'DraftKingsName': 'David Robertson',
#   'DraftKingsPlayerID': 328019,
#   'FanDuelName': 'David Robertson',
#   'FanDuelPlayerID': 5735,
#   'FantasyAlarmPlayerID': 101291,
#   'FantasyDraftName': 'David Robertson',
#   'FantasyDraftPlayerID': 885919,
#   'FirstName': 'David',
#   'GlobalTeamID': 10000029,
#   'Height': 71,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 30,
#   'LastName': 'Robertson',
#   'MLBAMID': 502085,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000248.png',
#   'PlayerID': 10000248,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10046,
#   'RotoworldPlayerID': 5595,
#   'Salary': 12000000,
#   'SportRadarPlayerID': '66048306-1c8b-45ff-b5c1-ddf5157829c5',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43512,
#   'StatsPlayerID': 328019,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 6698,
#   'YahooName': 'David Robertson',
#   'YahooPlayerID': 8287},
#  {'BatHand': 'L',
#   'BirthCity': 'Holguin',
#   'BirthCountry': 'Cuba',
#   'BirthDate': '1988-02-28T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Aroldis Chapman',
#   'DraftKingsPlayerID': 523977,
#   'FanDuelName': 'Aroldis Chapman',
#   'FanDuelPlayerID': 11108,
#   'FantasyAlarmPlayerID': 100111,
#   'FantasyDraftName': 'Aroldis Chapman',
#   'FantasyDraftPlayerID': 885944,
#   'FirstName': 'Aroldis',
#   'GlobalTeamID': 10000029,
#   'Height': 76,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 54,
#   'LastName': 'Chapman',
#   'MLBAMID': 547973,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000278.png',
#   'PlayerID': 10000278,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10866,
#   'RotoworldPlayerID': 5757,
#   'Salary': 17200000,
#   'SportRadarPlayerID': '17a14a6a-42f8-4f2e-86f3-42051584563e',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43898,
#   'StatsPlayerID': 523977,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 218,
#   'XmlTeamPlayerID': 9012,
#   'YahooName': 'Aroldis Chapman',
#   'YahooPlayerID': 8616},
#  {'BatHand': 'R',
#   'BirthCity': 'Latham',
#   'BirthCountry': 'USA',
#   'BirthDate': '1989-08-07T00:00:00',
#   'BirthState': 'NY',
#   'College': 'LYNN UNIVERSITY',
#   'DraftKingsName': 'Tommy Kahnle',
#   'DraftKingsPlayerID': 526323,
#   'FanDuelName': 'Tommy Kahnle',
#   'FanDuelPlayerID': 38217,
#   'FantasyAlarmPlayerID': 100157,
#   'FantasyDraftName': 'Tommy Kahnle',
#   'FantasyDraftPlayerID': 885921,
#   'FirstName': 'Tommy',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 48,
#   'LastName': 'Kahnle',
#   'MLBAMID': 592454,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000378.png',
#   'PlayerID': 10000378,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 11532,
#   'RotoworldPlayerID': 7685,
#   'Salary': 535000,
#   'SportRadarPlayerID': '257b1387-5dfa-4674-a3b7-6eb561ed2f06',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 115083,
#   'StatsPlayerID': 526323,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 230,
#   'XmlTeamPlayerID': 8779,
#   'YahooName': 'Tommy Kahnle',
#   'YahooPlayerID': 9653},
#  {'BatHand': 'R',
#   'BirthCity': 'Libertad de Barinas',
#   'BirthCountry': 'Venezuela',
#   'BirthDate': '1992-09-02T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Ronald Torreyes',
#   'DraftKingsPlayerID': 546565,
#   'FanDuelName': 'Ronald Torreyes',
#   'FanDuelPlayerID': 13451,
#   'FantasyAlarmPlayerID': 101205,
#   'FantasyDraftName': 'Ronald Torreyes',
#   'FantasyDraftPlayerID': 886040,
#   'FirstName': 'Ronald',
#   'GlobalTeamID': 10000029,
#   'Height': 68,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 74,
#   'LastName': 'Torreyes',
#   'MLBAMID': 591720,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000491.png',
#   'PlayerID': 10000491,
#   'Position': '2B',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12280,
#   'RotoworldPlayerID': 6788,
#   'Salary': 561900,
#   'SportRadarPlayerID': '30df3307-8d3c-406c-971c-ade93c45b7ab',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 108548,
#   'StatsPlayerID': 546565,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 155,
#   'XmlTeamPlayerID': 8765,
#   'YahooName': 'Ronald Torreyes',
#   'YahooPlayerID': 10088},
#  {'BatHand': 'R',
#   'BirthCity': 'Telford',
#   'BirthCountry': 'USA',
#   'BirthDate': '1980-06-15T00:00:00',
#   'BirthState': 'PA',
#   'College': 'Eastern Mennonite',
#   'DraftKingsName': 'Erik Kratz',
#   'DraftKingsPlayerID': 201707,
#   'FanDuelName': 'Erik Kratz',
#   'FanDuelPlayerID': 12428,
#   'FantasyAlarmPlayerID': 100143,
#   'FantasyDraftName': 'Erik Kratz',
#   'FantasyDraftPlayerID': 886016,
#   'FirstName': 'Erik',
#   'GlobalTeamID': 10000029,
#   'Height': 76,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 36,
#   'LastName': 'Kratz',
#   'MLBAMID': 456124,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000523.png',
#   'PlayerID': 10000523,
#   'Position': 'C',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10556,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '21a330cf-ed71-4e0d-b6ca-0aea5dc1017c',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 106913,
#   'StatsPlayerID': 201707,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 245,
#   'XmlTeamPlayerID': 7418,
#   'YahooName': 'Erik Kratz',
#   'YahooPlayerID': 8760},
#  {'BatHand': 'L',
#   'BirthCity': 'Lake Charles',
#   'BirthCountry': 'USA',
#   'BirthDate': '1984-08-07T00:00:00',
#   'BirthState': 'LA',
#   'College': 'Alabama',
#   'DraftKingsName': 'Wade LeBlanc',
#   'DraftKingsPlayerID': 326535,
#   'FanDuelName': 'Wade LeBlanc',
#   'FanDuelPlayerID': 6018,
#   'FantasyAlarmPlayerID': 100398,
#   'FantasyDraftName': 'Wade LeBlanc',
#   'FantasyDraftPlayerID': 871758,
#   'FirstName': 'Wade',
#   'GlobalTeamID': 10000029,
#   'Height': 75,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 38,
#   'LastName': 'LeBlanc',
#   'MLBAMID': 453281,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000556.png',
#   'PlayerID': 10000556,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9350,
#   'RotoworldPlayerID': 5135,
#   'Salary': None,
#   'SportRadarPlayerID': '5f368c8c-5ddb-4be8-9c59-ee5dd81c51cc',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43570,
#   'StatsPlayerID': 326535,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 210,
#   'XmlTeamPlayerID': None,
#   'YahooName': 'Wade LeBlanc',
#   'YahooPlayerID': 8353},
#  {'BatHand': 'R',
#   'BirthCity': 'Panorama',
#   'BirthCountry': 'USA',
#   'BirthDate': '1989-11-08T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'Giancarlo Stanton',
#   'DraftKingsPlayerID': 390316,
#   'FanDuelName': 'Giancarlo Stanton',
#   'FanDuelPlayerID': 12302,
#   'FantasyAlarmPlayerID': 100783,
#   'FantasyDraftName': 'Giancarlo Stanton',
#   'FantasyDraftPlayerID': 872643,
#   'FirstName': 'Giancarlo',
#   'GlobalTeamID': 10000029,
#   'Height': 78,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 27,
#   'LastName': 'Stanton',
#   'MLBAMID': 519317,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000690.png',
#   'PlayerID': 10000690,
#   'Position': 'RF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9901,
#   'RotoworldPlayerID': 5434,
#   'Salary': None,
#   'SportRadarPlayerID': 'b54ace79-5c94-45d1-873a-7ae90e5c6726',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 106937,
#   'StatsPlayerID': 390316,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 245,
#   'XmlTeamPlayerID': 3491,
#   'YahooName': 'Giancarlo Stanton',
#   'YahooPlayerID': 8634},
#  {'BatHand': 'L',
#   'BirthCity': 'Muncie',
#   'BirthCountry': 'USA',
#   'BirthDate': '1983-07-17T00:00:00',
#   'BirthState': 'IN',
#   'College': 'South Alabama',
#   'DraftKingsName': 'Adam Lind',
#   'DraftKingsPlayerID': 253777,
#   'FanDuelName': 'Adam Lind',
#   'FanDuelPlayerID': 5617,
#   'FantasyAlarmPlayerID': 100228,
#   'FantasyDraftName': 'Adam Lind',
#   'FantasyDraftPlayerID': 880614,
#   'FirstName': 'Adam',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 26,
#   'LastName': 'Lind',
#   'MLBAMID': 452252,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000740.png',
#   'PlayerID': 10000740,
#   'Position': '1B',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 8990,
#   'RotoworldPlayerID': 4044,
#   'Salary': None,
#   'SportRadarPlayerID': '36edf276-6c47-43aa-931c-ca4fd10e1025',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 42936,
#   'StatsPlayerID': 253777,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 5030,
#   'YahooName': 'Adam Lind',
#   'YahooPlayerID': 7859},
#  {'BatHand': 'R',
#   'BirthCity': 'Livermore',
#   'BirthCountry': 'USA',
#   'BirthDate': '1990-01-14T00:00:00',
#   'BirthState': 'CA',
#   'College': 'Santa Clara',
#   'DraftKingsName': 'J.R. Graham',
#   'DraftKingsPlayerID': 579841,
#   'FanDuelName': 'J.R. Graham',
#   'FanDuelPlayerID': 38025,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'J.R.',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Graham',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000747.png',
#   'PlayerID': 10000747,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12695,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 113514,
#   'StatsPlayerID': 579841,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 210,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': 'S',
#   'BirthCity': 'San Pedro',
#   'BirthCountry': 'USA',
#   'BirthDate': '1989-10-02T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'Aaron Hicks',
#   'DraftKingsPlayerID': 454371,
#   'FanDuelName': 'Aaron Hicks',
#   'FanDuelPlayerID': 13894,
#   'FantasyAlarmPlayerID': 100325,
#   'FantasyDraftName': 'Aaron Hicks',
#   'FantasyDraftPlayerID': 886067,
#   'FirstName': 'Aaron',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 31,
#   'LastName': 'Hicks',
#   'MLBAMID': 543305,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000777.png',
#   'PlayerID': 10000777,
#   'Position': 'CF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10470,
#   'RotoworldPlayerID': 5479,
#   'Salary': 1350000,
#   'SportRadarPlayerID': '4ea710f8-d2b5-42d4-ba58-5cb6e4517dfa',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 104534,
#   'StatsPlayerID': 454371,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 205,
#   'XmlTeamPlayerID': 8270,
#   'YahooName': 'Aaron Hicks',
#   'YahooPlayerID': 9325},
#  {'BatHand': 'R',
#   'BirthCity': 'New York',
#   'BirthCountry': 'USA',
#   'BirthDate': '1988-03-23T00:00:00',
#   'BirthState': 'NY',
#   'College': None,
#   'DraftKingsName': 'Dellin Betances',
#   'DraftKingsPlayerID': 327052,
#   'FanDuelName': 'Dellin Betances',
#   'FanDuelPlayerID': 13183,
#   'FantasyAlarmPlayerID': 100277,
#   'FantasyDraftName': 'Dellin Betances',
#   'FantasyDraftPlayerID': 885946,
#   'FirstName': 'Dellin',
#   'GlobalTeamID': 10000029,
#   'Height': 80,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 68,
#   'LastName': 'Betances',
#   'MLBAMID': 476454,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000831.png',
#   'PlayerID': 10000831,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9622,
#   'RotoworldPlayerID': 4792,
#   'Salary': 3000000,
#   'SportRadarPlayerID': '41d695be-d912-4a4f-a75f-6e1078c3362a',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 107174,
#   'StatsPlayerID': 327052,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 265,
#   'XmlTeamPlayerID': 6791,
#   'YahooName': 'Dellin Betances',
#   'YahooPlayerID': 9063},
#  {'BatHand': 'L',
#   'BirthCity': 'Vallejo',
#   'BirthCountry': 'USA',
#   'BirthDate': '1980-07-21T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'CC Sabathia',
#   'DraftKingsPlayerID': 8700,
#   'FanDuelName': 'CC Sabathia',
#   'FanDuelPlayerID': 5547,
#   'FantasyAlarmPlayerID': 100216,
#   'FantasyDraftName': 'CC Sabathia',
#   'FantasyDraftPlayerID': 885942,
#   'FirstName': 'CC',
#   'GlobalTeamID': 10000029,
#   'Height': 78,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 52,
#   'LastName': 'Sabathia',
#   'MLBAMID': 282332,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000848.png',
#   'PlayerID': 10000848,
#   'Position': 'SP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 6400,
#   'RotoworldPlayerID': 3149,
#   'Salary': 25000000,
#   'SportRadarPlayerID': '34c78a46-c798-4545-a05c-f9b693635e9b',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 41140,
#   'StatsPlayerID': 8700,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 300,
#   'XmlTeamPlayerID': 2488,
#   'YahooName': 'CC Sabathia',
#   'YahooPlayerID': 6603},
#  {'BatHand': 'L',
#   'BirthCity': 'Las Vegas',
#   'BirthCountry': 'USA',
#   'BirthDate': '1990-07-12T00:00:00',
#   'BirthState': 'NV',
#   'College': None,
#   'DraftKingsName': 'Chasen Shreve',
#   'DraftKingsPlayerID': 549074,
#   'FanDuelName': 'Chasen Shreve',
#   'FanDuelPlayerID': 39081,
#   'FantasyAlarmPlayerID': 100972,
#   'FantasyDraftName': 'Chasen Shreve',
#   'FantasyDraftPlayerID': 885951,
#   'FirstName': 'Chasen',
#   'GlobalTeamID': 10000029,
#   'Height': 76,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 45,
#   'LastName': 'Shreve',
#   'MLBAMID': 592741,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000849.png',
#   'PlayerID': 10000849,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 13585,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': 'df94012e-94b3-4cd2-8b51-6cc2e62c025e',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 109785,
#   'StatsPlayerID': 549074,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 11175,
#   'YahooName': 'Chasen Shreve',
#   'YahooPlayerID': 9768},
#  {'BatHand': 'R',
#   'BirthCity': 'Itami',
#   'BirthCountry': 'Japan',
#   'BirthDate': '1988-11-01T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Masahiro Tanaka',
#   'DraftKingsPlayerID': 491207,
#   'FanDuelName': 'Masahiro Tanaka',
#   'FanDuelPlayerID': 52268,
#   'FantasyAlarmPlayerID': 101110,
#   'FantasyDraftName': 'Masahiro Tanaka',
#   'FantasyDraftPlayerID': 885949,
#   'FirstName': 'Masahiro',
#   'GlobalTeamID': 10000029,
#   'Height': 75,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 19,
#   'LastName': 'Tanaka',
#   'MLBAMID': 547888,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000850.png',
#   'PlayerID': 10000850,
#   'Position': 'SP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10879,
#   'RotoworldPlayerID': 7573,
#   'Salary': 22000000,
#   'SportRadarPlayerID': 'fdfda40f-e77b-4cc2-a72c-11951460beda',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 116355,
#   'StatsPlayerID': 491207,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 218,
#   'XmlTeamPlayerID': 6984,
#   'YahooName': 'Masahiro Tanaka',
#   'YahooPlayerID': 9642},
#  {'BatHand': 'R',
#   'BirthCity': 'Birmingham',
#   'BirthCountry': 'USA',
#   'BirthDate': '1987-08-25T00:00:00',
#   'BirthState': 'AL',
#   'College': 'North Carolina',
#   'DraftKingsName': 'Adam Warren',
#   'DraftKingsPlayerID': 501312,
#   'FanDuelName': 'Adam Warren',
#   'FanDuelPlayerID': 13184,
#   'FantasyAlarmPlayerID': 100477,
#   'FantasyDraftName': 'Adam Warren',
#   'FantasyDraftPlayerID': 885947,
#   'FirstName': 'Adam',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 43,
#   'LastName': 'Warren',
#   'MLBAMID': 476589,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000851.png',
#   'PlayerID': 10000851,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 11083,
#   'RotoworldPlayerID': 6458,
#   'Salary': 2290000,
#   'SportRadarPlayerID': '6ea9ca2c-55ff-407d-99ef-8f3e741af0a7',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 107153,
#   'StatsPlayerID': 501312,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 225,
#   'XmlTeamPlayerID': 7860,
#   'YahooName': 'Adam Warren',
#   'YahooPlayerID': 9224},
#  {'BatHand': 'R',
#   'BirthCity': 'Lake Forest',
#   'BirthCountry': 'USA',
#   'BirthDate': '1988-11-22T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'Austin Romine',
#   'DraftKingsPlayerID': 390355,
#   'FanDuelName': 'Austin Romine',
#   'FanDuelPlayerID': 13009,
#   'FantasyAlarmPlayerID': 100800,
#   'FantasyDraftName': 'Austin Romine',
#   'FantasyDraftPlayerID': 886021,
#   'FirstName': 'Austin',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 27,
#   'LastName': 'Romine',
#   'MLBAMID': 519222,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000856.png',
#   'PlayerID': 10000856,
#   'Position': 'C',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9913,
#   'RotoworldPlayerID': 5800,
#   'Salary': 805000,
#   'SportRadarPlayerID': 'b8a69594-ffd7-4940-91fa-5cddeda6dd12',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 105138,
#   'StatsPlayerID': 390355,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 216,
#   'XmlTeamPlayerID': 4010,
#   'YahooName': 'Austin Romine',
#   'YahooPlayerID': 9082},
#  {'BatHand': 'R',
#   'BirthCity': 'Santo Domingo',
#   'BirthCountry': 'Dominican Republic',
#   'BirthDate': '1992-12-02T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Gary Sánchez',
#   'DraftKingsPlayerID': 549555,
#   'FanDuelName': 'Gary Sánchez',
#   'FanDuelPlayerID': 16945,
#   'FantasyAlarmPlayerID': 100804,
#   'FantasyDraftName': 'Gary Sánchez',
#   'FantasyDraftPlayerID': 886022,
#   'FirstName': 'Gary',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 24,
#   'LastName': 'Sanchez',
#   'MLBAMID': 596142,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000857.png',
#   'PlayerID': 10000857,
#   'Position': 'C',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 11159,
#   'RotoworldPlayerID': 5997,
#   'Salary': 557900,
#   'SportRadarPlayerID': 'b9ee6cb0-733c-4f27-88bf-847c42a6236d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 109323,
#   'StatsPlayerID': 549555,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 230,
#   'XmlTeamPlayerID': 7852,
#   'YahooName': 'Gary Sánchez',
#   'YahooPlayerID': 9097},
#  {'BatHand': 'L',
#   'BirthCity': 'Amsterdam',
#   'BirthCountry': 'Netherlands',
#   'BirthDate': '1990-02-18T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Didi Gregorius',
#   'DraftKingsPlayerID': 456349,
#   'FanDuelName': 'Didi Gregorius',
#   'FanDuelPlayerID': 13841,
#   'FantasyAlarmPlayerID': 100448,
#   'FantasyDraftName': 'Didi Gregorius',
#   'FantasyDraftPlayerID': 886055,
#   'FirstName': 'Didi',
#   'GlobalTeamID': 10000029,
#   'Height': 75,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 18,
#   'LastName': 'Gregorius',
#   'MLBAMID': 544369,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000859.png',
#   'PlayerID': 10000859,
#   'Position': 'SS',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 11257,
#   'RotoworldPlayerID': 6861,
#   'Salary': 5100000,
#   'SportRadarPlayerID': '69e46bb4-88b1-4deb-af10-334fcba65eee',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 104588,
#   'StatsPlayerID': 456349,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 205,
#   'XmlTeamPlayerID': 7469,
#   'YahooName': 'Didi Gregorius',
#   'YahooPlayerID': 9282},
#  {'BatHand': 'R',
#   'BirthCity': 'Conyers',
#   'BirthCountry': 'USA',
#   'BirthDate': '1991-09-06T00:00:00',
#   'BirthState': 'GA',
#   'College': None,
#   'DraftKingsName': 'Tyler Austin',
#   'DraftKingsPlayerID': 549178,
#   'FanDuelName': 'Tyler Austin',
#   'FanDuelPlayerID': 21699,
#   'FantasyAlarmPlayerID': 101306,
#   'FantasyDraftName': 'Tyler Austin',
#   'FantasyDraftPlayerID': 886078,
#   'FirstName': 'Tyler',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 26,
#   'LastName': 'Austin',
#   'MLBAMID': 592122,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000867.png',
#   'PlayerID': 10000867,
#   'Position': '1B',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12439,
#   'RotoworldPlayerID': 7066,
#   'Salary': None,
#   'SportRadarPlayerID': '6d9e52f8-7a4d-46b1-856e-05a2faa70c3d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 112688,
#   'StatsPlayerID': 549178,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 222,
#   'XmlTeamPlayerID': 8612,
#   'YahooName': 'Tyler Austin',
#   'YahooPlayerID': 9603},
#  {'BatHand': 'L',
#   'BirthCity': 'Madras',
#   'BirthCountry': 'USA',
#   'BirthDate': '1983-09-11T00:00:00',
#   'BirthState': 'OR',
#   'College': 'Oregon State',
#   'DraftKingsName': 'Jacoby Ellsbury',
#   'DraftKingsPlayerID': 294691,
#   'FanDuelName': 'Jacoby Ellsbury',
#   'FanDuelPlayerID': 5188,
#   'FantasyAlarmPlayerID': 100168,
#   'FantasyDraftName': 'Jacoby Ellsbury',
#   'FantasyDraftPlayerID': 886066,
#   'FirstName': 'Jacoby',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 22,
#   'LastName': 'Ellsbury',
#   'MLBAMID': 453056,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000868.png',
#   'PlayerID': 10000868,
#   'Position': 'CF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 8635,
#   'RotoworldPlayerID': 4207,
#   'Salary': 21142857,
#   'SportRadarPlayerID': '28e6daa5-fb40-49d9-9e58-04d113cd63b9',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43186,
#   'StatsPlayerID': 294691,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 5945,
#   'YahooName': 'Jacoby Ellsbury',
#   'YahooPlayerID': 7912},
#  {'BatHand': 'L',
#   'BirthCity': 'Holly Hill',
#   'BirthCountry': 'USA',
#   'BirthDate': '1983-08-24T00:00:00',
#   'BirthState': 'SC',
#   'College': 'Charleston',
#   'DraftKingsName': 'Brett Gardner',
#   'DraftKingsPlayerID': 291262,
#   'FanDuelName': 'Brett Gardner',
#   'FanDuelPlayerID': 5948,
#   'FantasyAlarmPlayerID': 100208,
#   'FantasyDraftName': 'Brett Gardner',
#   'FantasyDraftPlayerID': 886062,
#   'FirstName': 'Brett',
#   'GlobalTeamID': 10000029,
#   'Height': 71,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 11,
#   'LastName': 'Gardner',
#   'MLBAMID': 458731,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000870.png',
#   'PlayerID': 10000870,
#   'Position': 'LF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9623,
#   'RotoworldPlayerID': 4451,
#   'Salary': 12500000,
#   'SportRadarPlayerID': '32362986-6bba-443c-927d-8b87153caf0d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43513,
#   'StatsPlayerID': 291262,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 195,
#   'XmlTeamPlayerID': 5906,
#   'YahooName': 'Brett Gardner',
#   'YahooPlayerID': 8289},
#  {'BatHand': 'R',
#   'BirthCity': 'Nashville',
#   'BirthCountry': 'USA',
#   'BirthDate': '1989-11-07T00:00:00',
#   'BirthState': 'TN',
#   'College': 'Vanderbilt',
#   'DraftKingsName': 'Sonny Gray',
#   'DraftKingsPlayerID': 455516,
#   'FanDuelName': 'Sonny Gray',
#   'FanDuelPlayerID': 17064,
#   'FantasyAlarmPlayerID': 100771,
#   'FantasyDraftName': 'Sonny Gray',
#   'FantasyDraftPlayerID': 885958,
#   'FirstName': 'Sonny',
#   'GlobalTeamID': 10000029,
#   'Height': 70,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 55,
#   'LastName': 'Gray',
#   'MLBAMID': 543243,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000886.png',
#   'PlayerID': 10000886,
#   'Position': 'SP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12129,
#   'RotoworldPlayerID': 5506,
#   'Salary': 3575000,
#   'SportRadarPlayerID': 'b004cc6c-f00c-4b5d-917a-ee1abf92179d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 113206,
#   'StatsPlayerID': 455516,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 192,
#   'XmlTeamPlayerID': 9102,
#   'YahooName': 'Sonny Gray',
#   'YahooPlayerID': 9459},
#  {'BatHand': 'R',
#   'BirthCity': 'Orange Park',
#   'BirthCountry': 'USA',
#   'BirthDate': '1986-04-18T00:00:00',
#   'BirthState': 'FL',
#   'College': None,
#   'DraftKingsName': 'Billy Butler',
#   'DraftKingsPlayerID': 253221,
#   'FanDuelName': 'Billy Butler',
#   'FanDuelPlayerID': 5130,
#   'FantasyAlarmPlayerID': 101166,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Billy',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 36,
#   'LastName': 'Butler',
#   'MLBAMID': 456714,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10000919.png',
#   'PlayerID': 10000919,
#   'Position': 'DH',
#   'PositionCategory': 'DH',
#   'ProDebut': None,
#   'RotoWirePlayerID': 8282,
#   'RotoworldPlayerID': 152,
#   'Salary': 6666667,
#   'SportRadarPlayerID': '1b2abf1a-9d4f-4893-b238-ff38b8aaf05d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43130,
#   'StatsPlayerID': 253221,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 260,
#   'XmlTeamPlayerID': 4951,
#   'YahooName': 'Billy Butler',
#   'YahooPlayerID': 7634},
#  {'BatHand': 'R',
#   'BirthCity': 'Stillwater',
#   'BirthCountry': 'USA',
#   'BirthDate': '1980-01-15T00:00:00',
#   'BirthState': 'OK',
#   'College': None,
#   'DraftKingsName': 'Matt Holliday',
#   'DraftKingsPlayerID': 203180,
#   'FanDuelName': 'Matt Holliday',
#   'FanDuelPlayerID': 5178,
#   'FantasyAlarmPlayerID': 100270,
#   'FantasyDraftName': 'Matt Holliday',
#   'FantasyDraftPlayerID': 886094,
#   'FirstName': 'Matt',
#   'GlobalTeamID': 10000029,
#   'Height': 76,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 17,
#   'LastName': 'Holliday',
#   'MLBAMID': 407812,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001183.png',
#   'PlayerID': 10001183,
#   'Position': 'DH',
#   'PositionCategory': 'DH',
#   'ProDebut': None,
#   'RotoWirePlayerID': 7222,
#   'RotoworldPlayerID': 3850,
#   'Salary': 13000000,
#   'SportRadarPlayerID': '4083c6af-3416-4fb4-9b7e-d93e95640c86',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 41946,
#   'StatsPlayerID': 203180,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 240,
#   'XmlTeamPlayerID': 2901,
#   'YahooName': 'Matt Holliday',
#   'YahooPlayerID': 7311},
#  {'BatHand': 'S',
#   'BirthCity': 'Santa Ana',
#   'BirthCountry': 'USA',
#   'BirthDate': '1987-04-25T00:00:00',
#   'BirthState': 'CA',
#   'College': 'Long Beach State',
#   'DraftKingsName': 'Danny Espinosa',
#   'DraftKingsPlayerID': 454456,
#   'FanDuelName': 'Danny Espinosa',
#   'FanDuelPlayerID': 12562,
#   'FantasyAlarmPlayerID': 101093,
#   'FantasyDraftName': 'Danny Espinosa',
#   'FantasyDraftPlayerID': 872253,
#   'FirstName': 'Danny',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 14,
#   'LastName': 'Espinosa',
#   'MLBAMID': 457787,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001358.png',
#   'PlayerID': 10001358,
#   'Position': 'SS',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 10570,
#   'RotoworldPlayerID': 5912,
#   'Salary': None,
#   'SportRadarPlayerID': 'f9e77907-22a6-44dd-81f3-21c1dbdc06c9',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 105522,
#   'StatsPlayerID': 454456,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 205,
#   'XmlTeamPlayerID': 7405,
#   'YahooName': 'Danny Espinosa',
#   'YahooPlayerID': 8805},
#  {'BatHand': 'R',
#   'BirthCity': 'Tampa',
#   'BirthCountry': 'USA',
#   'BirthDate': '1984-10-30T00:00:00',
#   'BirthState': 'FL',
#   'College': 'Florida State',
#   'DraftKingsName': 'Shane Robinson',
#   'DraftKingsPlayerID': 326757,
#   'FanDuelName': 'Shane Robinson',
#   'FanDuelPlayerID': 6137,
#   'FantasyAlarmPlayerID': 100828,
#   'FantasyDraftName': 'Shane Robinson',
#   'FantasyDraftPlayerID': 872528,
#   'FirstName': 'Shane',
#   'GlobalTeamID': 10000029,
#   'Height': 69,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 25,
#   'LastName': 'Robinson',
#   'MLBAMID': 453203,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001393.png',
#   'PlayerID': 10001393,
#   'Position': 'OF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 9426,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': 'c16cff81-57ce-44d9-b6e3-f456c802503d',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 43792,
#   'StatsPlayerID': 326757,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 170,
#   'XmlTeamPlayerID': 6928,
#   'YahooName': 'Shane Robinson',
#   'YahooPlayerID': 8468},
#  {'BatHand': 'R',
#   'BirthCity': 'Miami Beach',
#   'BirthCountry': 'USA',
#   'BirthDate': '1985-04-10T00:00:00',
#   'BirthState': 'FL',
#   'College': 'North Carolina State',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': 12979,
#   'FantasyAlarmPlayerID': 101503,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Jonathan',
#   'GlobalTeamID': 10000029,
#   'Height': 69,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 89,
#   'LastName': 'Diaz',
#   'MLBAMID': 502409,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001404.png',
#   'PlayerID': 10001404,
#   'Position': 'SS',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12818,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': 'e47c2adc-7bcf-4d9d-aea3-efc24d5b52c8',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 155,
#   'XmlTeamPlayerID': 9705,
#   'YahooName': None,
#   'YahooPlayerID': 9447},
#  {'BatHand': 'R',
#   'BirthCity': 'Huntington Beach',
#   'BirthCountry': 'USA',
#   'BirthDate': '1990-04-20T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'Kyle Higashioka',
#   'DraftKingsPlayerID': 454957,
#   'FanDuelName': 'Kyle Higashioka',
#   'FanDuelPlayerID': 79918,
#   'FantasyAlarmPlayerID': 102317,
#   'FantasyDraftName': 'Kyle Higashioka',
#   'FantasyDraftPlayerID': 886027,
#   'FirstName': 'Kyle',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 30,
#   'LastName': 'Higashioka',
#   'MLBAMID': 543309,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001865.png',
#   'PlayerID': 10001865,
#   'Position': 'C',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 14572,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '85554a9a-0ff8-4886-844c-9b440ed94d61',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': 454957,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 202,
#   'XmlTeamPlayerID': None,
#   'YahooName': 'Kyle Higashioka',
#   'YahooPlayerID': 10678},
#  {'BatHand': 'R',
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': '1990-01-14T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': 101398,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Johnathan',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 62,
#   'LastName': 'Graham',
#   'MLBAMID': 543242,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10001881,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': 'a2a10235-a688-4a05-bd02-3d0f15f57bef',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 185,
#   'XmlTeamPlayerID': 9268,
#   'YahooName': 'J.R. Graham',
#   'YahooPlayerID': 9543},
#  {'BatHand': 'L',
#   'BirthCity': 'Memphis',
#   'BirthCountry': 'USA',
#   'BirthDate': '1992-11-09T00:00:00',
#   'BirthState': 'TN',
#   'College': None,
#   'DraftKingsName': 'Greg Bird',
#   'DraftKingsPlayerID': 597899,
#   'FanDuelName': 'Greg Bird',
#   'FanDuelPlayerID': 38140,
#   'FantasyAlarmPlayerID': 101777,
#   'FantasyDraftName': 'Greg Bird',
#   'FantasyDraftPlayerID': 886034,
#   'FirstName': 'Greg',
#   'GlobalTeamID': 10000029,
#   'Height': 76,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 33,
#   'LastName': 'Bird',
#   'MLBAMID': 595885,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10001908.png',
#   'PlayerID': 10001908,
#   'Position': '1B',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12246,
#   'RotoworldPlayerID': 7816,
#   'Salary': 545500,
#   'SportRadarPlayerID': '1881391a-a184-4410-af54-13007f989e74',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 115080,
#   'StatsPlayerID': 597899,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 220,
#   'XmlTeamPlayerID': None,
#   'YahooName': 'Greg Bird',
#   'YahooPlayerID': 9600},
#  {'BatHand': 'L',
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': '1992-12-04T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': 101970,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Andrew',
#   'GlobalTeamID': 10000029,
#   'Height': 72,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 27,
#   'LastName': 'Cave',
#   'MLBAMID': 595909,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10001909,
#   'Position': 'P',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '481ff280-9711-494a-9772-6a012b3899fe',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'L',
#   'UpcomingGameID': 53257,
#   'Weight': 179,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': 'R',
#   'BirthCity': 'Sabana De La Mar',
#   'BirthCountry': 'Dominican Republic',
#   'BirthDate': '1994-02-20T00:00:00',
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': 'Luis Severino',
#   'DraftKingsPlayerID': 657781,
#   'FanDuelName': 'Luis Severino',
#   'FanDuelPlayerID': 60644,
#   'FantasyAlarmPlayerID': 101771,
#   'FantasyDraftName': 'Luis Severino',
#   'FantasyDraftPlayerID': 885952,
#   'FirstName': 'Luis',
#   'GlobalTeamID': 10000029,
#   'Height': 74,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 40,
#   'LastName': 'Severino',
#   'MLBAMID': 622663,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10002077.png',
#   'PlayerID': 10002077,
#   'Position': 'SP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 13248,
#   'RotoworldPlayerID': 7860,
#   'Salary': 550975,
#   'SportRadarPlayerID': 'fa34724d-b540-4705-9d2c-7f50f81865b3',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 117345,
#   'StatsPlayerID': 657781,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 218,
#   'XmlTeamPlayerID': None,
#   'YahooName': 'Luis Severino',
#   'YahooPlayerID': 9879},
#  {'BatHand': 'R',
#   'BirthCity': 'Linden',
#   'BirthCountry': 'USA',
#   'BirthDate': '1992-04-26T00:00:00',
#   'BirthState': 'CA',
#   'College': None,
#   'DraftKingsName': 'Aaron Judge',
#   'DraftKingsPlayerID': 549847,
#   'FanDuelName': 'Aaron Judge',
#   'FanDuelPlayerID': 60643,
#   'FantasyAlarmPlayerID': 102226,
#   'FantasyDraftName': 'Aaron Judge',
#   'FantasyDraftPlayerID': 886079,
#   'FirstName': 'Aaron',
#   'GlobalTeamID': 10000029,
#   'Height': 79,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 99,
#   'LastName': 'Judge',
#   'MLBAMID': 592450,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/10002087.png',
#   'PlayerID': 10002087,
#   'Position': 'RF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 12959,
#   'RotoworldPlayerID': 7472,
#   'Salary': 544500,
#   'SportRadarPlayerID': '86f7390e-61bd-4556-8325-a6705c7f693b',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': 115269,
#   'StatsPlayerID': 549847,
#   'Status': 'Active',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 282,
#   'XmlTeamPlayerID': None,
#   'YahooName': 'Aaron Judge',
#   'YahooPlayerID': 9877},
#  {'BatHand': 'R',
#   'BirthCity': 'Decatur',
#   'BirthCountry': 'USA',
#   'BirthDate': '1994-09-06T00:00:00',
#   'BirthState': 'GA',
#   'College': None,
#   'DraftKingsName': 'Clint Frazier',
#   'DraftKingsPlayerID': 737437,
#   'FanDuelName': 'Clint Frazier',
#   'FanDuelPlayerID': 52150,
# ...
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Olivares',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008699,
#   'Position': 'OF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 15295,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Oswald',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Peraza',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008700,
#   'Position': 'SS',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 15296,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Cody',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Carroll',
#   'MLBAMID': 606944,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008746,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Raynel',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Espinal',
#   'MLBAMID': 642659,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008747,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Russell',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Wilson',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008748,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': 6764,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Isiah',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Gilliam',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008752,
#   'Position': 'OF',
#   'PositionCategory': 'OF',
#   'ProDebut': None,
#   'RotoWirePlayerID': 15330,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': None,
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Glenn',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': None,
#   'LastName': 'Otto',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008754,
#   'Position': 'P',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': 14945,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Brian',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 96,
#   'LastName': 'Keller',
#   'MLBAMID': 662144,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008848,
#   'Position': 'P',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Trevor',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 0,
#   'LastName': 'Lane',
#   'MLBAMID': 670065,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008917,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Non-Roster Invitee',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': 'R',
#   'BirthCity': 'Santiago',
#   'BirthCountry': 'Dominican Republic',
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Adonis',
#   'GlobalTeamID': 10000029,
#   'Height': 73,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 90,
#   'LastName': 'Rosa',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008919,
#   'Position': 'RP',
#   'PositionCategory': 'P',
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': 'R',
#   'UpcomingGameID': 53257,
#   'Weight': 160,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Josh',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 0,
#   'LastName': 'Rogers',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008920,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Will',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 18,
#   'LastName': 'Carter',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008943,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Andrew',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 94,
#   'LastName': 'Schwaab',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008945,
#   'Position': None,
#   'PositionCategory': None,
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': 53257,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None},
#  {'BatHand': None,
#   'BirthCity': None,
#   'BirthCountry': None,
#   'BirthDate': None,
#   'BirthState': None,
#   'College': 'None',
#   'DraftKingsName': None,
#   'DraftKingsPlayerID': None,
#   'FanDuelName': None,
#   'FanDuelPlayerID': None,
#   'FantasyAlarmPlayerID': None,
#   'FantasyDraftName': None,
#   'FantasyDraftPlayerID': None,
#   'FirstName': 'Donny',
#   'GlobalTeamID': 10000029,
#   'Height': None,
#   'HighSchool': None,
#   'InjuryBodyPart': 'Scrambled',
#   'InjuryNotes': 'Scrambled',
#   'InjuryStartDate': None,
#   'InjuryStatus': 'Scrambled',
#   'Jersey': 0,
#   'LastName': 'Sands',
#   'MLBAMID': None,
#   'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/mlb/low-res/0.png',
#   'PlayerID': 10008965,
#   'Position': 'C',
#   'PositionCategory': 'IF',
#   'ProDebut': None,
#   'RotoWirePlayerID': None,
#   'RotoworldPlayerID': None,
#   'Salary': None,
#   'SportRadarPlayerID': '',
#   'SportsDataID': '',
#   'SportsDirectPlayerID': None,
#   'StatsPlayerID': None,
#   'Status': 'Minors',
#   'Team': 'NYY',
#   'TeamID': 29,
#   'ThrowHand': None,
#   'UpcomingGameID': None,
#   'Weight': None,
#   'XmlTeamPlayerID': None,
#   'YahooName': None,
#   'YahooPlayerID': None}]

# %%
nyy_name_lookup = {}
for item in nyy:
    first_name = item['FirstName']
    last_name = item['LastName']
    nyy_name_lookup[first_name] = first_name + ','+ last_name

# %%
nyy_name_lookup
# Out:
# {'Aaron': 'Aaron,Dott',
#  'Abiatal': 'Abiatal,Avelino',
#  'Adam': 'Adam,Warren',
#  'Adonis': 'Adonis,Rosa',
#  'Albert': 'Albert,Abreu',
#  'Alexander': 'Alexander,Palma',
#  'Andrew': 'Andrew,Schwaab',
#  'Anthony': 'Anthony,Garcia',
#  'Antonio': 'Antonio,Cabello',
#  'Aroldis': 'Aroldis,Chapman',
#  'Austin': 'Austin,DeCarr',
#  'Ben': 'Ben,Heller',
#  'Billy': 'Billy,McKinney',
#  'Brady': 'Brady,Lail',
#  'Brandon': 'Brandon,Drury',
#  'Brett': 'Brett,Gardner',
#  'Brian': 'Brian,Keller',
#  'CC': 'CC,Sabathia',
#  'Cale': 'Cale,Coshow',
#  'Canaan': 'Canaan,Smith',
#  'Carlos': 'Carlos,Vidal',
#  'Chace': 'Chace,Numata',
#  'Chad': 'Chad,Green',
#  'Chance': 'Chance,Adams',
#  'Chasen': 'Chasen,Shreve',
#  'Chris': 'Chris,Gittens',
#  'Clarke': 'Clarke,Schmidt',
#  'Clint': 'Clint,Frazier',
#  'Cody': 'Cody,Carroll',
#  'Danny': 'Danny,Espinosa',
#  'David': 'David,Robertson',
#  'Deivi': 'Deivi,Garcia',
#  'Dellin': 'Dellin,Betances',
#  'Dermis': 'Dermis,Garcia',
#  'Didi': 'Didi,Gregorius',
#  'Diego': 'Diego,Castillo',
#  'Dillon': 'Dillon,Tate',
#  'Domingo': 'Domingo,Acevedo',
#  'Donny': 'Donny,Sands',
#  'Drew': 'Drew,Finley',
#  'Erik': 'Erik,Swanson',
#  'Estevan': 'Estevan,Florial',
#  'Evan': 'Evan,Rutckyj',
#  'Everson': 'Everson,Pereira',
#  'Francisco': 'Francisco,Diaz',
#  'Freicer': 'Freicer,Perez',
#  'Gary': 'Gary,Sanchez',
#  'Giancarlo': 'Giancarlo,Stanton',
#  'Giovanny': 'Giovanny,Gallegos',
#  'Glenn': 'Glenn,Otto',
#  'Gleyber': 'Gleyber,Torres',
#  'Gosuke': 'Gosuke,Katoh',
#  'Greg': 'Greg,Bird',
#  'Hyo-Jun': 'Hyo-Jun,Park',
#  'Isiah': 'Isiah,Gilliam',
#  'J.P.': 'J.P.,Feyereisen',
#  'J.R.': 'J.R.,Graham',
#  'JP': 'JP,Sears',
#  'Jace': 'Jace,Peterson',
#  'Jacoby': 'Jacoby,Ellsbury',
#  'Jake': 'Jake,Skole',
#  'James': 'James,Reeves',
#  'Jeff': 'Jeff,Hendrix',
#  'Jio': 'Jio,Orozco',
#  'Joe': 'Joe,Girardi',
#  'Johnathan': 'Johnathan,Graham',
#  'Jonathan': 'Jonathan,Loaisiga',
#  'Jordan': 'Jordan,Montgomery',
#  'Jorge': 'Jorge,Saez',
#  'Josh': 'Josh,Rogers',
#  'Juan': 'Juan,Then',
#  'Justus': 'Justus,Sheffield',
#  'Kellin': 'Kellin,Deglan',
#  'Kyle': 'Kyle,Holder',
#  'Leonardo': 'Leonardo,Molina',
#  'Luis': 'Luis,Medina',
#  'Masahiro': 'Masahiro,Tanaka',
#  'Matt': 'Matt,Sauer',
#  'Michael': 'Michael,King',
#  'Miguel': 'Miguel,Flames',
#  'Nathan': 'Nathan,Mikolas',
#  'Nelson': 'Nelson,Gomez',
#  'Nick': 'Nick,Nelson',
#  'Nolan': 'Nolan,Martinez',
#  'Omar Luis': 'Omar Luis,Rodriguez',
#  'Oswald': 'Oswald,Peraza',
#  'Pablo': 'Pablo,Olivares',
#  'Radley': 'Radley,Haddad',
#  'Raimfer': 'Raimfer,Salinas',
#  'Rashad': 'Rashad,Crawford',
#  'Raynel': 'Raynel,Espinal',
#  'Reiver': 'Reiver,Sanmartin',
#  'Roberto': 'Roberto,Chirinos',
#  'Ronald': 'Ronald,Torreyes',
#  'Ronny': 'Ronny,Rojas',
#  'Rony': 'Rony,Garcia',
#  'Russell': 'Russell,Wilson',
#  'Ryan': 'Ryan,McBroom',
#  'Shane': 'Shane,Robinson',
#  'Sonny': 'Sonny,Gray',
#  'Stephen': 'Stephen,Tarpley',
#  'Thairo': 'Thairo,Estrada',
#  'Tommy': 'Tommy,Kahnle',
#  'Trevor': 'Trevor,Lane',
#  'Tyler': 'Tyler,Wade',
#  'Wade': 'Wade,LeBlanc',
#  'Wilkerman': 'Wilkerman,Garcia',
#  'Wilkin': 'Wilkin,Castillo',
#  'Will': 'Will,Carter'}

# %%
##########################
######## question 3.1#####


# continue with the driver
# get the players page, id: sp_parent
player_element = driver.find_element_by_id('sp_parent')
player_element.click()

# %%
# get the Yankees, id:sp_hitting_team_id
yankees = driver.find_element_by_id('sp_hitting_team_id')
yankees.click()

# %%
yankees_select = Select(yankees)
# value for NY Yankees is '147'
yankees_select.select_by_value('147')

# %%
# get the season 2017
season_element = driver.find_element_by_id('sp_hitting_season')
season_element.click()

# %%
season_select = Select(season_element)
season_select.select_by_value('2017')

# %%
# get the split
split_element = driver.find_element_by_id('sp_hitting_hitting_splits')
split_element.click()

# %%
split_select = Select(split_element)
split_select.select_by_value('')

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
soup_thead_tr = soup.thead.tr
player_header = [t.text.replace('▼','').replace('▲', '') for t in soup_thead_tr.findAll('th')]
# player_header
#print (soup.prettify())

# %%
soup_tbody = soup.tbody
player_stats = []
soup_tbody_tr = soup_tbody.findAll('tr')
for tr in soup_tbody_tr:
    #print(tr)
    player_detail = [t.text for t in tr.findAll('td')]
    #print(team_detail)
    player_stats.append(player_detail)
    
df_player = pd.DataFrame(data= player_stats, columns=player_header)

### save data for all the player in NY Yankees
df_player.to_csv('Question_3.csv', sep=',',index_label=False)

# %%
with open ('Question_3.csv', 'r') as q3:
    df_player= pd.read_csv(q3, sep=',')
    
df_player_top = df_player.loc[lambda df_hr: df_player.AB.astype(int) > 30, :]
df_player_top
# df_player_avg = df_player_top.convert_objects(convert_numeric=True)
df_player_top.AVG.astype(float)
df_player_avg = df_player_top.sort_values(['AVG'], ascending=False)
best_player_name = df_player_avg.iloc[0]['Player'].strip()
best_player_pos = df_player_avg.iloc[0]['Pos'].strip()
#df_player_avg
player_index = best_player_name[0]
best_top1 = [[best_player_name, best_player_pos]]
answer_q3_1 = pd.DataFrame(best_top1, columns=['Full Name', 'Position'])
answer_q3_1
print (answer_q3_1)
# Out:
#    Full Name Position
# 0  Cooper, G       1B

# %%
# get the full name of the best player
cg = driver.find_element_by_link_text(best_player_name)
cg.click()

# %%
full_name = driver.find_element_by_class_name('full-name').text
print ('Full name:', full_name, ';', 'Position:',best_player_pos)
best_p = [[full_name, best_player_pos]]
answer_q3_1 = pd.DataFrame(best_p, columns=['Full Name', 'Position'])
answer_q3_1
# answer_q3.to_csv('Answer_q3.csv', sep=',',index_label=False)
# Out:
# Full name: Garrett N. Cooper ; Position: 1B
#            Full Name Position
# 0  Garrett N. Cooper       1B

# %%
##########################
######## question 3.2#####

with open ('Question_3.csv', 'r') as q3:
    df_player_q3= pd.read_csv(q3, sep=',')

# df_player_q3= pd.read_csv('Question_3.csv', sep=',')
position = ['RF', 'CF', 'LF']
df_player_outfield = df_player_q3.loc[df_player_q3['Pos'].isin(position)]
df_player_outfield_avg = df_player_outfield.sort_values(['AVG'], ascending=False)
best_outfield_player_name = df_player_outfield_avg.iloc[0].Player.strip()
best_outfield_player_pos = df_player_outfield_avg.iloc[0]['Pos'].strip()
#pd.options.display.max_columns=99

# %%
driver.back()

# %%
ga = driver.find_element_by_link_text(best_outfield_player_name)
ga.click()

# %%
full_name2 = driver.find_element_by_class_name('full-name').text
print ('Full name:', full_name2, ';', 'Position:',best_outfield_player_pos)
#driver.close()
best_p = [[full_name, best_player_pos], [full_name2, best_outfield_player_pos]]
answer_q3 = pd.DataFrame(best_p, columns=['Full Name', 'Position'])
#answer_q3 = pd.DataFrame(best_p, columns=['Full Name', 'Position'])
# Out:
# Full name: Aaron James Judge ; Position: RF

# %%
answer_q3.to_csv('Answer_3.csv', sep=',',index_label='INDEX')

# %% [markdown]
# ## Question 4
# - Which player in the American League had the most at bats in the 2015 regular season? Please give his full name, full team name, and position.

# %%
import random
import time

# %%
#driver = webdriver.Firefox(executable_path=r'/Users/xusibocn/Desktop/SIT/Course/BIA 660 Web Analytics/BIA660D_master/Lecture_06/geckodriver')
driver = webdriver.Firefox(executable_path='./geckodriver')

# %%
driver.get('http://www.mlb.com')
wait = WebDriverWait(driver, 10)
stats_header_bar = wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'megamenu-navbar-overflow__menu-item--stats')))
print('The stats dropdown in the header was loaded successfully. The mouse will move over the element after a short delay')
normal_delay = random.normalvariate(2, 0.5)
stats_header_bar = driver.find_element_by_class_name('megamenu-navbar-overflow__menu-item-link--stats')
# Out:
# The stats dropdown in the header was loaded successfully. The mouse will move over the element after a short delay

# %%
stats_header_bar.click()
stats_header_bar.click()

# %%
# get the season 2015
season_element = driver.find_element_by_id('sp_hitting_season')
season_element.click()

# %%
season_select = Select(season_element)
season_select.select_by_value('2015')

# %%
# get the regular season
gametype_element = driver.find_element_by_id('sp_hitting_game_type')
gametype_element.click()

# %%
gametype_select = Select(gametype_element)
gametype_select.select_by_value("'R'")

# %%
# sort by 'AB'
ab_bottom = driver.find_element_by_tag_name('thead')
ab = ab_bottom.find_element_by_class_name('dg-ab')
ab.click()

# %%
ab_tbody = driver.find_element_by_tag_name('tbody')

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
#soup_tbody_tr = soup.tbody.tr
#soup_tbody_tr
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
soup_tr = soup.thead.tr
player_header = [t.text.replace('▼','') for t in soup_tr.findAll('th')]

soup_tbody = soup.tbody
player_stats = []
#for t in soup_tbody:
    #print (t.tr)
soup_tbody_tr = soup_tbody.findAll('tr')
for tr in soup_tbody_tr:
    #print(tr)
    player_detail = [t.text.strip() for t in tr.findAll('td')]
    #print(team_detail)
    player_stats.append(player_detail)

player_stats
#player_detail = [t.text.strip() for t in soup_tbody_tr.findAll('td')]
player_name_q4 = player_detail[1].strip()
#player_pos = player_detail[5].strip()

# %%
###### save the scarpe data for the question 4 ####
player_detail = [player_detail]
player_detail_df = pd.DataFrame(player_stats, columns=player_header)
player_detail_df.to_csv('Question_4.csv', sep=',',index_label='INDEX')
#player_detail_df

# %%
q4_name = driver.find_element_by_link_text(player_name_q4)
q4_name.click()

# %%
team_name = driver.find_element_by_class_name('dropdown.team').text.split('\n')[0].strip()

# %%
full_name = driver.find_element_by_class_name('full-name').text
print ('Full name:', full_name, ';', 'Team:',team_name,';', 'Pos:', player_pos)
# Out:
# Full name: José Carlos Altuve ; Team: Houston Astros ; Pos: 2B

# %%
best_p4 = [[full_name, team_name, player_pos]]
answer_q4 = pd.DataFrame(best_p4, columns=['Full Name','Team', 'Position'])

# %%
answer_q4.to_csv('Answer_4.csv', sep = ',', index_label='INDEX')

# %%
driver.close()

# %% [markdown]
# ## Question 5
# - Which players from the 2014 All-star game were born in Latin America (google a country list)? Please give their full name and the full name of the team they play for.

# %%
# latin_coun = '''Argentina;Belize;Bolivia;Brazil;Chile;Colombia;Costa Rica;Ecuador;El Salvador;Falkland Islands;French Guiana;Guatemala;Guyana;Honduras;Mexico;Nicaragua;Panama;Paraguay;Peru;Suriname;Uruguay;Venezuela'''

# %%
latin_coun ='''Argentina;Bolivia;Brazil;Chile;Colombia;Costa Rica;Cuba;Dominican Republic;Ecuador;El Salvador;French Guiana;Guadeloupe;Guatemala;Haiti;Honduras;Martinique;Mexico;Nicaragua;Panama;Paraguay;Peru;Puerto Rico;Saint Barthélemy;Saint Martin;Uruguay;Venezuela'''

# %%
driver = webdriver.Firefox(executable_path='./geckodriver')

# %%
driver.get('http://www.mlb.com')
wait = WebDriverWait(driver, 10)
stats_header_bar = wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'megamenu-navbar-overflow__menu-item--stats')))
print('The stats dropdown in the header was loaded successfully. The mouse will move over the element after a short delay')
normal_delay = random.normalvariate(2, 0.5)
stats_header_bar = driver.find_element_by_class_name('megamenu-navbar-overflow__menu-item-link--stats')
# Out:
# The stats dropdown in the header was loaded successfully. The mouse will move over the element after a short delay

# %%
stats_header_bar.click()
stats_header_bar.click()

# %%
# get the season 2015
season_element = driver.find_element_by_id('sp_hitting_season')
season_element.click()

# %%
season_select = Select(season_element)
season_select.select_by_value('2014')

# %%
# get the regular season
gametype_element = driver.find_element_by_id('sp_hitting_game_type')
gametype_element.click()

# %%
gametype_select = Select(gametype_element)
gametype_select.select_by_value("'A'")

# %%
latin_countries = latin_coun.split(';')
latin_countries
# Out:
# ['Argentina',
#  'Bolivia',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'French Guiana',
#  'Guadeloupe',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Martinique',
#  'Mexico',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Puerto Rico',
#  'Saint Barthélemy',
#  'Saint Martin',
#  'Uruguay',
#  'Venezuela']

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = bs4.BeautifulSoup(data_html,'html5lib')
soup_tbody = soup.tbody
player_name_link_list = []
soup_tbody_tr = soup_tbody.findAll('tr')
for tr in soup_tbody_tr:
    #t.get_attribute('href')
    names = [t.a for t in tr.findAll('td')][1]
    names_link = str(names['href'])
    #print (names_link)
    player_name_link_list.append(names_link)


#player_name_list = player_name_list[:5]
href_link=[]
player_name_link_list[1]
for a in player_name_link_list:
    href_p = ''.join(["//a[contains(@href, '", a, "')]"])
    href_link.append(href_p)
#href_link

# %%
#driver.find_element_by_xpath(href_link[1]).click()

# %%
p_detail = []
final = []
for p_name_href in href_link:
    #href= str(''.join(["//a[contains(@href, '", p_name_href, "')]"]))
    newpage_name = driver.find_element_by_xpath(p_name_href)
    #newpage_name = driver.find_element_by_link_text(p_name)
    newpage_name.click()
    wait = WebDriverWait(driver, 10)
    p_bio = wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'player-bio'))).text
    #for c in latin_countries:
        #if c in p_bio:
    #p_born = p_bio.text.split('\n')[1]
    #p_full_name = p_bio.text.split('\n')[0]
            #normal_delay = random.normalvariate(2, 0.5)
            #wait = WebDriverWait(driver, 10)
            #p_bio = wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'dropdown.team')))
            #p_team_name = driver.find_element_by_class_name('dropdown.team').text.split('\n')[0].strip()
            #p_detail = [p_bio, p_team_name]
            #final.append(p_detail)
    wait = WebDriverWait(driver, 10)
    p_team_name = driver.find_element_by_class_name('dropdown.team').text.split('\n')[0].strip()
    p_detail = [p_bio, p_team_name]
    final.append(p_detail)    
    time.sleep(normal_delay)
    driver.back()
    time.sleep(normal_delay)

# %%
#final

# %%
df_final = pd.DataFrame(final , columns=['Bio', 'Team'])
df_final.to_csv('Question_5.csv', sep=',', index_label='Index')

# %%
driver.close()

# %%
player_final = []
for a in final:
    pp_name = a[0].split('\n')[0]
    pp_team = a[1]
    player_bio = [pp_name, pp_team]
    player_final.append(player_bio)

# %%
player_final
# Out:
# [['Aramis Nin Ramirez', 'Pittsburgh Pirates'],
#  ['Alexei Fernando Ramirez', 'Tampa Bay Rays'],
#  ['Jose Miguel Cabrera', 'Detroit Tigers'],
#  ['José Dariel Abreu', 'Chicago White Sox'],
#  ['José Antonio Bautista', 'Toronto Blue Jays'],
#  ['Robinson Jose Canó', 'Seattle Mariners'],
#  ['Starlin DeJesus Castro', 'Miami Marlins'],
#  ['Yoenis Céspedes', 'New York Mets'],
#  ['Nelson Ramon Cruz', 'Seattle Mariners'],
#  ['Carlos Argelis Gómez', 'Tampa Bay Rays'],
#  ['Miguel Angel Montero', 'Washington Nationals'],
#  ['Salvador Johan Perez', 'Kansas City Royals'],
#  ['Yasiel Puig', 'Los Angeles Dodgers'],
#  ['José Carlos Altuve', 'Houston Astros'],
#  ['Erick Johan Aybar', 'Minnesota Twins'],
#  ['Adrian Beltre', 'Texas Rangers']]

# %%
import csv
with open('Question_5.csv', 'r') as f:
    reader = csv.reader(f)
    all_star_player = list(reader)
    
latin_countries = latin_coun.split(';')
player_final = []
for a in all_star_player:
    for coun in latin_countries:
        if coun in a[1]:
            pp_name = a[1].split('\n')[0]
            pp_team = a[2]
            player_bio = [pp_name, pp_team]
            player_final.append(player_bio)
# Out:
# [['Aramis Nin Ramirez', 'Pittsburgh Pirates'],
#  ['Alexei Fernando Ramirez', 'Tampa Bay Rays'],
#  ['Jose Miguel Cabrera', 'Detroit Tigers'],
#  ['José Dariel Abreu', 'Chicago White Sox'],
#  ['José Antonio Bautista', 'Toronto Blue Jays'],
#  ['Robinson Jose Canó', 'Seattle Mariners'],
#  ['Starlin DeJesus Castro', 'Miami Marlins'],
#  ['Yoenis Céspedes', 'New York Mets'],
#  ['Nelson Ramon Cruz', 'Seattle Mariners'],
#  ['Carlos Argelis Gómez', 'Tampa Bay Rays'],
#  ['Miguel Angel Montero', 'Select Team'],
#  ['Salvador Johan Perez', 'Select Team'],
#  ['Yasiel Puig', 'Los Angeles Dodgers'],
#  ['José Carlos Altuve', 'Houston Astros'],
#  ['Erick Johan Aybar', 'Minnesota Twins'],
#  ['Adrian Beltre', 'Texas Rangers']]

# %%
#print (final)
df_final = pd.DataFrame(player_final , columns=['Full Name', 'Team'])
df_final
# Out:
#                   Full Name                  Team
# 0        Aramis Nin Ramirez    Pittsburgh Pirates
# 1   Alexei Fernando Ramirez        Tampa Bay Rays
# 2       Jose Miguel Cabrera        Detroit Tigers
# 3         José Dariel Abreu     Chicago White Sox
# 4     José Antonio Bautista     Toronto Blue Jays
# 5        Robinson Jose Canó      Seattle Mariners
# 6    Starlin DeJesus Castro         Miami Marlins
# 7           Yoenis Céspedes         New York Mets
# 8         Nelson Ramon Cruz      Seattle Mariners
# 9      Carlos Argelis Gómez        Tampa Bay Rays
# 10     Miguel Angel Montero  Washington Nationals
# 11     Salvador Johan Perez    Kansas City Royals
# 12              Yasiel Puig   Los Angeles Dodgers
# 13       José Carlos Altuve        Houston Astros
# 14        Erick Johan Aybar       Minnesota Twins
# 15            Adrian Beltre         Texas Rangers

# %%
# save the answer for question 5
#df_final.to_csv('Question_5.csv', sep=',',index_label=False)
df_final.to_csv('Answer_5.csv', sep=',', index_label='Index')

# %% [markdown]
# ## Question 6
# - Please print the 2016 regular season schedule for the Houston Astros in chronological order. Each line printed to the screen should be in the following format:
#     - opponent Team Name, game date, stadium name, city, state

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'ff202b724b714dc3aa66aa292a78b964',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/mlb/stats/json/Games/2016?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    #print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
import json

#stat = json.loads(data)

# %%
# save json of team scheduel
with open('MLB_v3_Stats_Teams_Active_Schedules.json', 'w') as outfile:
    json.dump(stat, outfile)

# %%
# read json of team scheduel
with open('MLB_v3_Stats_Teams_Active_Schedules.json', 'r') as outfile:
    stat = json.load(outfile)
stat
# Out:
# [{'Attendance': None,
#   'AwayTeam': 'NYM',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 18,
#   'AwayTeamMoneyLine': 7,
#   'AwayTeamProbablePitcherID': 10000794,
#   'AwayTeamRuns': 3,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000794,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-03T20:37:00',
#   'Day': '2016-04-03T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 67,
#   'ForecastTempLow': 55,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44928,
#   'GlobalAwayTeamID': 10000018,
#   'GlobalGameID': 10044928,
#   'GlobalHomeTeamID': 10000005,
#   'HomeTeam': 'KC',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 10,
#   'HomeTeamID': 5,
#   'HomeTeamMoneyLine': 118,
#   'HomeTeamProbablePitcherID': 10000522,
#   'HomeTeamRuns': 4,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000522,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000794,
#   'Outs': None,
#   'OverUnder': None,
#   'PointSpread': None,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000505,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 33,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000522},
#  {'Attendance': None,
#   'AwayTeam': 'STL',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 5,
#   'AwayTeamID': 31,
#   'AwayTeamMoneyLine': 6,
#   'AwayTeamProbablePitcherID': 10001162,
#   'AwayTeamRuns': 1,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001162,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-03T13:05:00',
#   'Day': '2016-04-03T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 63,
#   'ForecastTempLow': 37,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44926,
#   'GlobalAwayTeamID': 10000031,
#   'GlobalGameID': 10044926,
#   'GlobalHomeTeamID': 10000004,
#   'HomeTeam': 'PIT',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 10,
#   'HomeTeamID': 4,
#   'HomeTeamMoneyLine': -134,
#   'HomeTeamProbablePitcherID': 10000977,
#   'HomeTeamRuns': 4,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000977,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001162,
#   'Outs': None,
#   'OverUnder': None,
#   'PointSpread': None,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 29,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000977},
#  {'Attendance': None,
#   'AwayTeam': 'TOR',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 3,
#   'AwayTeamMoneyLine': 7,
#   'AwayTeamProbablePitcherID': 10001305,
#   'AwayTeamRuns': 5,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001305,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-03T16:05:00',
#   'Day': '2016-04-03T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 34,
#   'ForecastTempLow': 31,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44927,
#   'GlobalAwayTeamID': 10000003,
#   'GlobalGameID': 10044927,
#   'GlobalHomeTeamID': 10000011,
#   'HomeTeam': 'TB',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 7,
#   'HomeTeamID': 11,
#   'HomeTeamMoneyLine': -135,
#   'HomeTeamProbablePitcherID': 10001187,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001187,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001187,
#   'Outs': None,
#   'OverUnder': None,
#   'PointSpread': None,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10001957,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 18,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001305},
#  {'Attendance': None,
#   'AwayTeam': 'SF',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 16,
#   'AwayTeamID': 15,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10001105,
#   'AwayTeamRuns': 13,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001105,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T14:10:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 73,
#   'ForecastTempLow': 58,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44930,
#   'GlobalAwayTeamID': 10000015,
#   'GlobalGameID': 10044930,
#   'GlobalHomeTeamID': 10000032,
#   'HomeTeam': 'MIL',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 9,
#   'HomeTeamID': 32,
#   'HomeTeamMoneyLine': -129,
#   'HomeTeamProbablePitcherID': 10000709,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000709,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000709,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 19,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001105},
#  {'Attendance': None,
#   'AwayTeam': 'CHC',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 12,
#   'AwayTeamID': 9,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000184,
#   'AwayTeamRuns': 10,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000184,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T22:05:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 43,
#   'ForecastTempLow': 34,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44939,
#   'GlobalAwayTeamID': 10000009,
#   'GlobalGameID': 10044939,
#   'GlobalHomeTeamID': 10000021,
#   'HomeTeam': 'LAA',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 3,
#   'HomeTeamID': 21,
#   'HomeTeamMoneyLine': 143,
#   'HomeTeamProbablePitcherID': 10000564,
#   'HomeTeamRuns': 0,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000564,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000564,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 28,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000184},
#  {'Attendance': None,
#   'AwayTeam': 'COL',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 16,
#   'AwayTeamID': 23,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000373,
#   'AwayTeamRuns': 11,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000373,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T21:40:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 59,
#   'ForecastTempLow': 32,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44938,
#   'GlobalAwayTeamID': 10000023,
#   'GlobalGameID': 10044938,
#   'GlobalHomeTeamID': 10000014,
#   'HomeTeam': 'ARI',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 13,
#   'HomeTeamID': 14,
#   'HomeTeamMoneyLine': -225,
#   'HomeTeamProbablePitcherID': 10000613,
#   'HomeTeamRuns': 5,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000613,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000613,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 54,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001451},
#  {'Attendance': None,
#   'AwayTeam': 'HOU',
#   'AwayTeamErrors': None,
#   'AwayTeamHits': None,
#   'AwayTeamID': 30,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000469,
#   'AwayTeamRuns': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000469,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T13:00:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 67,
#   'ForecastTempLow': 54,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44929,
#   'GlobalAwayTeamID': 10000030,
#   'GlobalGameID': 10044929,
#   'GlobalHomeTeamID': 10000029,
#   'HomeTeam': 'NYY',
#   'HomeTeamErrors': None,
#   'HomeTeamHits': None,
#   'HomeTeamID': 29,
#   'HomeTeamMoneyLine': None,
#   'HomeTeamProbablePitcherID': 10000850,
#   'HomeTeamRuns': None,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000850,
#   'Inning': None,
#   'InningHalf': None,
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': None,
#   'Outs': None,
#   'OverUnder': None,
#   'PointSpread': None,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': 47521,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 35,
#   'Status': 'Postponed',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': None},
#  {'Attendance': None,
#   'AwayTeam': 'BOS',
#   'AwayTeamErrors': None,
#   'AwayTeamHits': None,
#   'AwayTeamID': 25,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000421,
#   'AwayTeamRuns': None,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000421,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T16:10:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 58,
#   'ForecastTempLow': 45,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44933,
#   'GlobalAwayTeamID': 10000025,
#   'GlobalGameID': 10044933,
#   'GlobalHomeTeamID': 10000010,
#   'HomeTeam': 'CLE',
#   'HomeTeamErrors': None,
#   'HomeTeamHits': None,
#   'HomeTeamID': 10,
#   'HomeTeamMoneyLine': -211,
#   'HomeTeamProbablePitcherID': 10000335,
#   'HomeTeamRuns': None,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000335,
#   'Inning': None,
#   'InningHalf': None,
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': None,
#   'Outs': None,
#   'OverUnder': 7.3,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': 47522,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 10,
#   'Status': 'Postponed',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': None},
#  {'Attendance': None,
#   'AwayTeam': 'PHI',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 6,
#   'AwayTeamID': 12,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000012,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000012,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T16:10:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 76,
#   'ForecastTempLow': 57,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44935,
#   'GlobalAwayTeamID': 10000012,
#   'GlobalGameID': 10044935,
#   'GlobalHomeTeamID': 10000002,
#   'HomeTeam': 'CIN',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 6,
#   'HomeTeamID': 2,
#   'HomeTeamMoneyLine': -197,
#   'HomeTeamProbablePitcherID': 10003197,
#   'HomeTeamRuns': 6,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10003197,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000013,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 64,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001342},
#  {'Attendance': None,
#   'AwayTeam': 'MIN',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 20,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000759,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000759,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T16:45:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 45,
#   'ForecastTempLow': 29,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44931,
#   'GlobalAwayTeamID': 10000020,
#   'GlobalGameID': 10044931,
#   'GlobalHomeTeamID': 10000019,
#   'HomeTeam': 'BAL',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 11,
#   'HomeTeamID': 19,
#   'HomeTeamMoneyLine': 169,
#   'HomeTeamProbablePitcherID': 10000113,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000113,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001198,
#   'Outs': None,
#   'OverUnder': 10.1,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 22,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000094},
#  {'Attendance': None,
#   'AwayTeam': 'TOR',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 3,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10001288,
#   'AwayTeamRuns': 5,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001288,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T19:10:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': None,
#   'ForecastTempLow': None,
#   'ForecastWindChill': None,
#   'ForecastWindDirection': None,
#   'ForecastWindSpeed': None,
#   'GameID': 44937,
#   'GlobalAwayTeamID': 10000003,
#   'GlobalGameID': 10044937,
#   'GlobalHomeTeamID': 10000011,
#   'HomeTeam': 'TB',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 9,
#   'HomeTeamID': 11,
#   'HomeTeamMoneyLine': -135,
#   'HomeTeamProbablePitcherID': 10001207,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001207,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001207,
#   'Outs': None,
#   'OverUnder': 9.0,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10001957,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 18,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001288},
#  {'Attendance': None,
#   'AwayTeam': 'LAD',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 19,
#   'AwayTeamID': 1,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000618,
#   'AwayTeamRuns': 16,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000618,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T19:05:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 82,
#   'ForecastTempLow': 65,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44936,
#   'GlobalAwayTeamID': 10000001,
#   'GlobalGameID': 10044936,
#   'GlobalHomeTeamID': 10000033,
#   'HomeTeam': 'SD',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 4,
#   'HomeTeamID': 33,
#   'HomeTeamMoneyLine': 197,
#   'HomeTeamProbablePitcherID': 10001031,
#   'HomeTeamRuns': 0,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001031,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001031,
#   'Outs': None,
#   'OverUnder': 6.8,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 1,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000618},
#  {'Attendance': None,
#   'AwayTeam': 'SEA',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 4,
#   'AwayTeamID': 13,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10001065,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001065,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T16:05:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 71,
#   'ForecastTempLow': 46,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44932,
#   'GlobalAwayTeamID': 10000013,
#   'GlobalGameID': 10044932,
#   'GlobalHomeTeamID': 10000028,
#   'HomeTeam': 'TEX',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 1,
#   'HomeTeamID': 28,
#   'HomeTeamMoneyLine': -140,
#   'HomeTeamProbablePitcherID': 10000931,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000931,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001065,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10001259,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 21,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000931},
#  {'Attendance': None,
#   'AwayTeam': 'CHW',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 16,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000249,
#   'AwayTeamRuns': 4,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000249,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T22:05:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 77,
#   'ForecastTempLow': 56,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44940,
#   'GlobalAwayTeamID': 10000016,
#   'GlobalGameID': 10044940,
#   'GlobalHomeTeamID': 10000024,
#   'HomeTeam': 'OAK',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 7,
#   'HomeTeamID': 24,
#   'HomeTeamMoneyLine': 146,
#   'HomeTeamProbablePitcherID': 10000839,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000839,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000839,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000248,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 23,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000249},
#  {'Attendance': None,
#   'AwayTeam': 'WSH',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 9,
#   'AwayTeamID': 35,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000426,
#   'AwayTeamRuns': 4,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000426,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-04T16:10:00',
#   'Day': '2016-04-04T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 82,
#   'ForecastTempLow': 65,
#   'ForecastWindChill': 0,
#   'ForecastWindDirection': 0,
#   'ForecastWindSpeed': 0,
#   'GameID': 44934,
#   'GlobalAwayTeamID': 10000035,
#   'GlobalGameID': 10044934,
#   'GlobalHomeTeamID': 10000026,
#   'HomeTeam': 'ATL',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 4,
#   'HomeTeamID': 26,
#   'HomeTeamMoneyLine': 180,
#   'HomeTeamProbablePitcherID': 10000066,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000066,
#   'Inning': 10,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000892,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000942,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 2,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001352},
#  {'Attendance': None,
#   'AwayTeam': 'DET',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 13,
#   'AwayTeamID': 17,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000432,
#   'AwayTeamRuns': 9,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000432,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T19:10:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 89,
#   'ForecastTempLow': 76,
#   'ForecastWindChill': 91,
#   'ForecastWindDirection': 50,
#   'ForecastWindSpeed': 24,
#   'GameID': 44943,
#   'GlobalAwayTeamID': 10000017,
#   'GlobalGameID': 10044943,
#   'GlobalHomeTeamID': 10000022,
#   'HomeTeam': 'MIA',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 11,
#   'HomeTeamID': 22,
#   'HomeTeamMoneyLine': 118,
#   'HomeTeamProbablePitcherID': 10000096,
#   'HomeTeamRuns': 7,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000096,
#   'Inning': 11,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000143,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000414,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 57,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10003254},
#  {'Attendance': None,
#   'AwayTeam': 'BOS',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 12,
#   'AwayTeamID': 25,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000421,
#   'AwayTeamRuns': 6,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000421,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T13:10:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': None,
#   'ForecastTempLow': None,
#   'ForecastWindChill': None,
#   'ForecastWindDirection': None,
#   'ForecastWindSpeed': None,
#   'GameID': 47522,
#   'GlobalAwayTeamID': 10000025,
#   'GlobalGameID': 10047522,
#   'GlobalHomeTeamID': 10000010,
#   'HomeTeam': 'CLE',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 5,
#   'HomeTeamID': 10,
#   'HomeTeamMoneyLine': -128,
#   'HomeTeamProbablePitcherID': 10000335,
#   'HomeTeamRuns': 2,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000335,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000335,
#   'Outs': None,
#   'OverUnder': 6.8,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': 50639,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 10,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2018-03-04T12:17:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000421},
#  {'Attendance': None,
#   'AwayTeam': 'COL',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 10,
#   'AwayTeamID': 23,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000367,
#   'AwayTeamRuns': 6,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000367,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T21:40:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 67,
#   'ForecastTempLow': 46,
#   'ForecastWindChill': 68,
#   'ForecastWindDirection': 332,
#   'ForecastWindSpeed': 28,
#   'GameID': 44947,
#   'GlobalAwayTeamID': 10000023,
#   'GlobalGameID': 10044947,
#   'GlobalHomeTeamID': 10000014,
#   'HomeTeam': 'ARI',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 16,
#   'HomeTeamID': 14,
#   'HomeTeamMoneyLine': -146,
#   'HomeTeamProbablePitcherID': 10000059,
#   'HomeTeamRuns': 12,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000059,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000366,
#   'Outs': None,
#   'OverUnder': 10.1,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 54,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001332},
#  {'Attendance': None,
#   'AwayTeam': 'CHC',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 10,
#   'AwayTeamID': 9,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000193,
#   'AwayTeamRuns': 6,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000193,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T22:05:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 47,
#   'ForecastTempLow': 31,
#   'ForecastWindChill': 36,
#   'ForecastWindDirection': 129,
#   'ForecastWindSpeed': 20,
#   'GameID': 44948,
#   'GlobalAwayTeamID': 10000009,
#   'GlobalGameID': 10044948,
#   'GlobalHomeTeamID': 10000021,
#   'HomeTeam': 'LAA',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 4,
#   'HomeTeamID': 21,
#   'HomeTeamMoneyLine': 138,
#   'HomeTeamProbablePitcherID': 10000555,
#   'HomeTeamRuns': 1,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000555,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000555,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 28,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000193},
#  {'Attendance': None,
#   'AwayTeam': 'LAD',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 6,
#   'AwayTeamID': 1,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000889,
#   'AwayTeamRuns': 3,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000889,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T22:10:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 81,
#   'ForecastTempLow': 66,
#   'ForecastWindChill': 82,
#   'ForecastWindDirection': 315,
#   'ForecastWindSpeed': 15,
#   'GameID': 44950,
#   'GlobalAwayTeamID': 10000001,
#   'GlobalGameID': 10044950,
#   'GlobalHomeTeamID': 10000033,
#   'HomeTeam': 'SD',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 2,
#   'HomeTeamID': 33,
#   'HomeTeamMoneyLine': 123,
#   'HomeTeamProbablePitcherID': 10000519,
#   'HomeTeamRuns': 0,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000519,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000519,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000617,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 1,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000889},
#  {'Attendance': None,
#   'AwayTeam': 'SF',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 15,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000282,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000282,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T20:10:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 77,
#   'ForecastTempLow': 59,
#   'ForecastWindChill': 76,
#   'ForecastWindDirection': 315,
#   'ForecastWindSpeed': 12,
#   'GameID': 44946,
#   'GlobalAwayTeamID': 10000015,
#   'GlobalGameID': 10044946,
#   'GlobalHomeTeamID': 10000032,
#   'HomeTeam': 'MIL',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 6,
#   'HomeTeamID': 32,
#   'HomeTeamMoneyLine': 135,
#   'HomeTeamProbablePitcherID': 10000707,
#   'HomeTeamRuns': 1,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000707,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000707,
#   'Outs': None,
#   'OverUnder': 9.0,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10001107,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 19,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000282},
#  {'Attendance': None,
#   'AwayTeam': 'HOU',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 6,
#   'AwayTeamID': 30,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000469,
#   'AwayTeamRuns': 5,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000469,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T13:05:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': None,
#   'ForecastTempLow': None,
#   'ForecastWindChill': None,
#   'ForecastWindDirection': None,
#   'ForecastWindSpeed': None,
#   'GameID': 47521,
#   'GlobalAwayTeamID': 10000030,
#   'GlobalGameID': 10047521,
#   'GlobalHomeTeamID': 10000029,
#   'HomeTeam': 'NYY',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 4,
#   'HomeTeamID': 29,
#   'HomeTeamMoneyLine': 123,
#   'HomeTeamProbablePitcherID': 10000850,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000850,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000831,
#   'Outs': None,
#   'OverUnder': 7.3,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': 50634,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000467,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 35,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2018-03-04T12:17:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000469},
#  {'Attendance': None,
#   'AwayTeam': 'CHW',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 12,
#   'AwayTeamID': 16,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000247,
#   'AwayTeamRuns': 5,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000247,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T22:05:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 82,
#   'ForecastTempLow': 60,
#   'ForecastWindChill': 78,
#   'ForecastWindDirection': 304,
#   'ForecastWindSpeed': 12,
#   'GameID': 44949,
#   'GlobalAwayTeamID': 10000016,
#   'GlobalGameID': 10044949,
#   'GlobalHomeTeamID': 10000024,
#   'HomeTeam': 'OAK',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 11,
#   'HomeTeamID': 24,
#   'HomeTeamMoneyLine': 119,
#   'HomeTeamProbablePitcherID': 10000880,
#   'HomeTeamRuns': 4,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000880,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000884,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000248,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 23,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000240},
#  {'Attendance': None,
#   'AwayTeam': 'NYM',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 6,
#   'AwayTeamID': 18,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10000805,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000805,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T16:15:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 46,
#   'ForecastTempLow': 31,
#   'ForecastWindChill': 38,
#   'ForecastWindDirection': 388,
#   'ForecastWindSpeed': 24,
#   'GameID': 44941,
#   'GlobalAwayTeamID': 10000018,
#   'GlobalGameID': 10044941,
#   'GlobalHomeTeamID': 10000005,
#   'HomeTeam': 'KC',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 3,
#   'HomeTeamID': 5,
#   'HomeTeamMoneyLine': 123,
#   'HomeTeamProbablePitcherID': 10001079,
#   'HomeTeamRuns': 0,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001079,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001079,
#   'Outs': None,
#   'OverUnder': 9.6,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000790,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 33,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000805},
#  {'Attendance': None,
#   'AwayTeam': 'STL',
#   'AwayTeamErrors': 1,
#   'AwayTeamHits': 9,
#   'AwayTeamID': 31,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10001161,
#   'AwayTeamRuns': 5,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001161,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T19:05:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 64,
#   'ForecastTempLow': 39,
#   'ForecastWindChill': 58,
#   'ForecastWindDirection': 152,
#   'ForecastWindSpeed': 20,
#   'GameID': 44942,
#   'GlobalAwayTeamID': 10000031,
#   'GlobalGameID': 10044942,
#   'GlobalHomeTeamID': 10000004,
#   'HomeTeam': 'PIT',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 13,
#   'HomeTeamID': 4,
#   'HomeTeamMoneyLine': -114,
#   'HomeTeamProbablePitcherID': 10000802,
#   'HomeTeamRuns': 6,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000802,
#   'Inning': 11,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001156,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 29,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000418},
#  {'Attendance': None,
#   'AwayTeam': 'TOR',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 10,
#   'AwayTeamID': 3,
#   'AwayTeamMoneyLine': None,
#   'AwayTeamProbablePitcherID': 10001303,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001303,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-04-05T19:10:00',
#   'Day': '2016-04-05T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 34,
#   'ForecastTempLow': 11,
#   'ForecastWindChill': 25,
#   'ForecastWindDirection': 236,
#   'ForecastWindSpeed': 15,
#   'GameID': 44944,
#   'GlobalAwayTeamID': 10000003,
#   'GlobalGameID': 10044944,
#   'GlobalHomeTeamID': 10000011,
#   'HomeTeam': 'TB',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 7,
#   'HomeTeamID': 11,
#   'HomeTeamMoneyLine': -118,
#   'HomeTeamProbablePitcherID': 10001203,
#   'HomeTeamRuns': 3,
# ...
#   'GlobalHomeTeamID': 10000012,
#   'HomeTeam': 'PHI',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 6,
#   'HomeTeamID': 12,
#   'HomeTeamMoneyLine': 175,
#   'HomeTeamProbablePitcherID': 10000012,
#   'HomeTeamRuns': 2,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000012,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000012,
#   'Outs': None,
#   'OverUnder': 9.0,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 51,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001290},
#  {'Attendance': None,
#   'AwayTeam': 'LAD',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 1,
#   'AwayTeamMoneyLine': -270,
#   'AwayTeamProbablePitcherID': 10000618,
#   'AwayTeamRuns': 3,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000618,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T15:40:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 113,
#   'ForecastTempLow': 85,
#   'ForecastWindChill': 92,
#   'ForecastWindDirection': 281,
#   'ForecastWindSpeed': 12,
#   'GameID': 45905,
#   'GlobalAwayTeamID': 10000001,
#   'GlobalGameID': 10045905,
#   'GlobalHomeTeamID': 10000014,
#   'HomeTeam': 'ARI',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 5,
#   'HomeTeamID': 14,
#   'HomeTeamMoneyLine': 246,
#   'HomeTeamProbablePitcherID': 10000007,
#   'HomeTeamRuns': 2,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000007,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000007,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000617,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 54,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000618},
#  {'Attendance': None,
#   'AwayTeam': 'CHC',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 12,
#   'AwayTeamID': 9,
#   'AwayTeamMoneyLine': 155,
#   'AwayTeamProbablePitcherID': 10000189,
#   'AwayTeamRuns': 4,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000189,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T16:05:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 93,
#   'ForecastTempLow': 73,
#   'ForecastWindChill': 74,
#   'ForecastWindDirection': 202,
#   'ForecastWindSpeed': 7,
#   'GameID': 45907,
#   'GlobalAwayTeamID': 10000009,
#   'GlobalGameID': 10045907,
#   'GlobalHomeTeamID': 10000035,
#   'HomeTeam': 'WSH',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 10,
#   'HomeTeamID': 35,
#   'HomeTeamMoneyLine': -169,
#   'HomeTeamProbablePitcherID': 10001350,
#   'HomeTeamRuns': 5,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001350,
#   'Inning': 12,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000004,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 53,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001119},
#  {'Attendance': None,
#   'AwayTeam': 'CLE',
#   'AwayTeamErrors': 3,
#   'AwayTeamHits': 5,
#   'AwayTeamID': 10,
#   'AwayTeamMoneyLine': -157,
#   'AwayTeamProbablePitcherID': 10000335,
#   'AwayTeamRuns': 4,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000335,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T20:15:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 109,
#   'ForecastTempLow': 84,
#   'ForecastWindChill': 86,
#   'ForecastWindDirection': 264,
#   'ForecastWindSpeed': 15,
#   'GameID': 45915,
#   'GlobalAwayTeamID': 10000010,
#   'GlobalGameID': 10045915,
#   'GlobalHomeTeamID': 10000005,
#   'HomeTeam': 'KC',
#   'HomeTeamErrors': 2,
#   'HomeTeamHits': 11,
#   'HomeTeamID': 5,
#   'HomeTeamMoneyLine': 145,
#   'HomeTeamProbablePitcherID': 10001025,
#   'HomeTeamRuns': 10,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001025,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000335,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 33,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001025},
#  {'Attendance': None,
#   'AwayTeam': 'TEX',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 11,
#   'AwayTeamID': 28,
#   'AwayTeamMoneyLine': 156,
#   'AwayTeamProbablePitcherID': 10001243,
#   'AwayTeamRuns': 7,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001243,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T22:05:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 71,
#   'ForecastTempLow': 61,
#   'ForecastWindChill': 58,
#   'ForecastWindDirection': 309,
#   'ForecastWindSpeed': 20,
#   'GameID': 45917,
#   'GlobalAwayTeamID': 10000028,
#   'GlobalGameID': 10045917,
#   'GlobalHomeTeamID': 10000024,
#   'HomeTeam': 'OAK',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 7,
#   'HomeTeamID': 24,
#   'HomeTeamMoneyLine': -170,
#   'HomeTeamProbablePitcherID': 10000886,
#   'HomeTeamRuns': 5,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000886,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000967,
#   'Outs': None,
#   'OverUnder': 9.0,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000659,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 23,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001248},
#  {'Attendance': None,
#   'AwayTeam': 'PIT',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 5,
#   'AwayTeamID': 4,
#   'AwayTeamMoneyLine': 174,
#   'AwayTeamProbablePitcherID': 10000979,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000979,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T19:10:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 96,
#   'ForecastTempLow': 72,
#   'ForecastWindChill': 72,
#   'ForecastWindDirection': 355,
#   'ForecastWindSpeed': 7,
#   'GameID': 45911,
#   'GlobalAwayTeamID': 10000004,
#   'GlobalGameID': 10045911,
#   'GlobalHomeTeamID': 10000018,
#   'HomeTeam': 'NYM',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 21,
#   'HomeTeamID': 18,
#   'HomeTeamMoneyLine': -189,
#   'HomeTeamProbablePitcherID': 10000805,
#   'HomeTeamRuns': 12,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000805,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000979,
#   'Outs': None,
#   'OverUnder': 7.9,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 8,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000805},
#  {'Attendance': None,
#   'AwayTeam': 'NYY',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 7,
#   'AwayTeamID': 29,
#   'AwayTeamMoneyLine': -117,
#   'AwayTeamProbablePitcherID': 10000843,
#   'AwayTeamRuns': 3,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000843,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T15:10:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 102,
#   'ForecastTempLow': 61,
#   'ForecastWindChill': 60,
#   'ForecastWindDirection': 202,
#   'ForecastWindSpeed': 12,
#   'GameID': 45903,
#   'GlobalAwayTeamID': 10000029,
#   'GlobalGameID': 10045903,
#   'GlobalHomeTeamID': 10000023,
#   'HomeTeam': 'COL',
#   'HomeTeamErrors': 1,
#   'HomeTeamHits': 14,
#   'HomeTeamID': 23,
#   'HomeTeamMoneyLine': -117,
#   'HomeTeamProbablePitcherID': 10000367,
#   'HomeTeamRuns': 6,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10000367,
#   'Inning': 9,
#   'InningHalf': 'T',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10000843,
#   'Outs': None,
#   'OverUnder': 13.0,
#   'PointSpread': 1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10005350,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 44,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000367},
#  {'Attendance': None,
#   'AwayTeam': 'HOU',
#   'AwayTeamErrors': 0,
#   'AwayTeamHits': 10,
#   'AwayTeamID': 30,
#   'AwayTeamMoneyLine': 139,
#   'AwayTeamProbablePitcherID': 10000470,
#   'AwayTeamRuns': 4,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10000470,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T19:15:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 105,
#   'ForecastTempLow': 83,
#   'ForecastWindChill': 91,
#   'ForecastWindDirection': 231,
#   'ForecastWindSpeed': 20,
#   'GameID': 45913,
#   'GlobalAwayTeamID': 10000030,
#   'GlobalGameID': 10045913,
#   'GlobalHomeTeamID': 10000031,
#   'HomeTeam': 'STL',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 9,
#   'HomeTeamID': 31,
#   'HomeTeamMoneyLine': -151,
#   'HomeTeamProbablePitcherID': 10001162,
#   'HomeTeamRuns': 1,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001162,
#   'Inning': 9,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001159,
#   'Outs': None,
#   'OverUnder': 9.6,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': 10000468,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 41,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10000476},
#  {'Attendance': None,
#   'AwayTeam': 'SEA',
#   'AwayTeamErrors': 2,
#   'AwayTeamHits': 9,
#   'AwayTeamID': 13,
#   'AwayTeamMoneyLine': 135,
#   'AwayTeamProbablePitcherID': 10001199,
#   'AwayTeamRuns': 2,
#   'AwayTeamStartingPitcher': 'Scrambled',
#   'AwayTeamStartingPitcherID': 10001199,
#   'Balls': None,
#   'Channel': None,
#   'CurrentHitter': 'Scrambled',
#   'CurrentHitterID': None,
#   'CurrentHittingTeamID': None,
#   'CurrentPitcher': 'Scrambled',
#   'CurrentPitcherID': None,
#   'CurrentPitchingTeamID': None,
#   'DateTime': '2016-06-15T19:10:00',
#   'Day': '2016-06-15T00:00:00',
#   'DueUpHitterID1': None,
#   'DueUpHitterID2': None,
#   'DueUpHitterID3': None,
#   'ForecastDescription': 'Scrambled',
#   'ForecastTempHigh': 96,
#   'ForecastTempLow': 90,
#   'ForecastWindChill': 91,
#   'ForecastWindDirection': 214,
#   'ForecastWindSpeed': 12,
#   'GameID': 45912,
#   'GlobalAwayTeamID': 10000013,
#   'GlobalGameID': 10045912,
#   'GlobalHomeTeamID': 10000011,
#   'HomeTeam': 'TB',
#   'HomeTeamErrors': 0,
#   'HomeTeamHits': 9,
#   'HomeTeamID': 11,
#   'HomeTeamMoneyLine': -146,
#   'HomeTeamProbablePitcherID': 10001207,
#   'HomeTeamRuns': 3,
#   'HomeTeamStartingPitcher': 'Scrambled',
#   'HomeTeamStartingPitcherID': 10001207,
#   'Inning': 13,
#   'InningHalf': 'B',
#   'IsClosed': True,
#   'LastPlay': 'Scrambled',
#   'LosingPitcher': 'Scrambled',
#   'LosingPitcherID': 10001201,
#   'Outs': None,
#   'OverUnder': 8.5,
#   'PointSpread': -1.7,
#   'PointSpreadAwayTeamMoneyLine': None,
#   'PointSpreadHomeTeamMoneyLine': None,
#   'RescheduledFromGameID': None,
#   'RescheduledGameID': None,
#   'RunnerOnFirst': None,
#   'RunnerOnSecond': None,
#   'RunnerOnThird': None,
#   'SavingPitcher': 'Scrambled',
#   'SavingPitcherID': None,
#   'Season': 2016,
#   'SeasonType': 1,
#   'StadiumID': 18,
#   'Status': 'Final',
#   'Strikes': None,
#   'Updated': '2017-10-20T14:01:45',
#   'WinningPitcher': 'Scrambled',
#   'WinningPitcherID': 10001186},
#  ...]

# %%
game = []
# match_date = []
for item in stat:
    if item['HomeTeam']=='HOU':
        #team = item['HomeTeam']
        opn_team = item['AwayTeam']
        date= item['DateTime']
        stadium_ID = item['StadiumID']
        opn_ID = item['AwayTeamID']
        #status = item['Status']
        game_detail = [opn_team,opn_ID, date, stadium_ID]
        game.append(game_detail)
    elif item['AwayTeam'] == 'HOU':
        #team = item['AwayTeam']
        opn_team = item['HomeTeam']
        date= item['DateTime']
        stadium_ID = item['StadiumID']
        opn_ID = item['HomeTeamID']
        #status = item['Status']
        game_detail = [opn_team,opn_ID, date, stadium_ID]
        game.append(game_detail)

# %%
game
# Out:
# [['NYY', 29, '2016-04-04T13:00:00', 35],
#  ['NYY', 29, '2016-04-05T13:05:00', 35],
#  ['NYY', 29, '2016-04-06T19:05:00', 35],
#  ['NYY', 29, '2016-04-07T16:15:00', 35],
#  ['MIL', 32, '2016-04-08T20:10:00', 19],
#  ['MIL', 32, '2016-04-09T19:10:00', 19],
#  ['MIL', 32, '2016-04-10T14:10:00', 19],
#  ['KC', 5, '2016-04-11T20:10:00', 63],
#  ['KC', 5, '2016-04-12T20:10:00', 63],
#  ['KC', 5, '2016-04-13T20:10:00', 63],
#  ['KC', 5, '2016-04-14T20:10:00', 63],
#  ['DET', 17, '2016-04-15T20:10:00', 63],
#  ['DET', 17, '2016-04-16T19:10:00', 63],
#  ['DET', 17, '2016-04-17T14:10:00', 63],
#  ['TEX', 28, '2016-04-19T20:05:00', 21],
#  ['TEX', 28, '2016-04-20T20:05:00', 21],
#  ['TEX', 28, '2016-04-21T20:05:00', 21],
#  ['BOS', 25, '2016-04-22T20:10:00', 63],
#  ['BOS', 25, '2016-04-23T16:05:00', 63],
#  ['BOS', 25, '2016-04-24T20:05:00', 63],
#  ['SEA', 13, '2016-04-25T22:10:00', 65],
#  ['SEA', 13, '2016-04-26T22:10:00', 65],
#  ['SEA', 13, '2016-04-27T22:10:00', 65],
#  ['OAK', 24, '2016-04-29T22:05:00', 23],
#  ['OAK', 24, '2016-04-30T16:05:00', 23],
#  ['OAK', 24, '2016-05-01T16:05:00', 23],
#  ['MIN', 20, '2016-05-02T20:10:00', 63],
#  ['MIN', 20, '2016-05-03T20:10:00', 63],
#  ['MIN', 20, '2016-05-04T20:10:00', 63],
#  ['SEA', 13, '2016-05-05T20:10:00', 63],
#  ['SEA', 13, '2016-05-06T20:10:00', 63],
#  ['SEA', 13, '2016-05-07T19:10:00', 63],
#  ['SEA', 13, '2016-05-08T14:10:00', 63],
#  ['CLE', 10, '2016-05-09T20:10:00', 63],
#  ['CLE', 10, '2016-05-10T20:10:00', 63],
#  ['CLE', 10, '2016-05-11T14:10:00', 63],
#  ['BOS', 25, '2016-05-12T19:10:00', 50],
#  ['BOS', 25, '2016-05-13T19:10:00', 50],
#  ['BOS', 25, '2016-05-14T13:05:00', 50],
#  ['BOS', 25, '2016-05-15T13:35:00', 50],
#  ['CHW', 16, '2016-05-17T20:10:00', 25],
#  ['CHW', 16, '2016-05-18T20:10:00', 25],
#  ['CHW', 16, '2016-05-19T20:10:00', 25],
#  ['TEX', 28, '2016-05-20T20:10:00', 63],
#  ['TEX', 28, '2016-05-21T19:15:00', 63],
#  ['TEX', 28, '2016-05-22T14:10:00', 63],
#  ['BAL', 19, '2016-05-24T20:10:00', 63],
#  ['BAL', 19, '2016-05-25T20:10:00', 63],
#  ['BAL', 19, '2016-05-26T20:10:00', 63],
#  ['LAA', 21, '2016-05-27T22:05:00', 28],
#  ['LAA', 21, '2016-05-28T22:05:00', 28],
#  ['LAA', 21, '2016-05-29T15:35:00', 28],
#  ['ARI', 14, '2016-05-30T16:10:00', 54],
#  ['ARI', 14, '2016-05-31T15:40:00', 54],
#  ['ARI', 14, '2016-06-01T20:10:00', 63],
#  ['ARI', 14, '2016-06-02T14:10:00', 63],
#  ['OAK', 24, '2016-06-03T20:10:00', 63],
#  ['OAK', 24, '2016-06-04T16:10:00', 63],
#  ['OAK', 24, '2016-06-05T14:10:00', 63],
#  ['TEX', 28, '2016-06-06T20:05:00', 21],
#  ['TEX', 28, '2016-06-07T20:05:00', 21],
#  ['TEX', 28, '2016-06-08T20:05:00', 21],
#  ['TEX', 28, '2016-06-09T14:05:00', 21],
#  ['TB', 11, '2016-06-10T19:10:00', 18],
#  ['TB', 11, '2016-06-11T16:10:00', 18],
#  ['TB', 11, '2016-06-12T13:10:00', 18],
#  ['STL', 31, '2016-06-14T20:15:00', 41],
#  ['STL', 31, '2016-06-15T19:15:00', 41],
#  ['CIN', 2, '2016-06-17T20:10:00', 63],
#  ['CIN', 2, '2016-06-18T16:10:00', 63],
#  ['CIN', 2, '2016-06-19T14:10:00', 63],
#  ['LAA', 21, '2016-06-20T20:10:00', 63],
#  ['LAA', 21, '2016-06-21T20:10:00', 63],
#  ['LAA', 21, '2016-06-22T14:10:00', 63],
#  ['KC', 5, '2016-06-24T20:15:00', 33],
#  ['KC', 5, '2016-06-25T19:15:00', 33],
#  ['KC', 5, '2016-06-26T14:15:00', 33],
#  ['LAA', 21, '2016-06-27T22:05:00', 28],
#  ['LAA', 21, '2016-06-28T22:05:00', 28],
#  ['LAA', 21, '2016-06-29T15:35:00', 28],
#  ['CHW', 16, '2016-07-01T20:10:00', 63],
#  ['CHW', 16, '2016-07-02T16:10:00', 63],
#  ['CHW', 16, '2016-07-03T14:10:00', 63],
#  ['SEA', 13, '2016-07-04T14:10:00', 63],
#  ['SEA', 13, '2016-07-05T20:10:00', 63],
#  ['SEA', 13, '2016-07-06T20:10:00', 63],
#  ['OAK', 24, '2016-07-07T20:10:00', 63],
#  ['OAK', 24, '2016-07-08T20:10:00', 63],
#  ['OAK', 24, '2016-07-09T16:10:00', 63],
#  ['OAK', 24, '2016-07-10T14:10:00', 63],
#  ['SEA', 13, '2016-07-15T22:10:00', 65],
#  ['SEA', 13, '2016-07-16T16:10:00', 65],
#  ['SEA', 13, '2016-07-17T16:10:00', 65],
#  ['OAK', 24, '2016-07-18T22:05:00', 23],
#  ['OAK', 24, '2016-07-19T22:05:00', 23],
#  ['OAK', 24, '2016-07-20T15:35:00', 23],
#  ['LAA', 21, '2016-07-22T20:10:00', 63],
#  ['LAA', 21, '2016-07-23T19:10:00', 63],
#  ['LAA', 21, '2016-07-24T14:10:00', 63],
#  ['NYY', 29, '2016-07-25T20:10:00', 63],
#  ['NYY', 29, '2016-07-26T20:10:00', 63],
#  ['NYY', 29, '2016-07-27T20:10:00', 63],
#  ['DET', 17, '2016-07-29T19:10:00', 62],
#  ['DET', 17, '2016-07-30T19:10:00', 62],
#  ['DET', 17, '2016-07-31T13:10:00', 62],
#  ['TOR', 3, '2016-08-01T20:10:00', 63],
#  ['TOR', 3, '2016-08-02T20:10:00', 63],
#  ['TOR', 3, '2016-08-03T20:10:00', 63],
#  ['TOR', 3, '2016-08-04T20:10:00', 63],
#  ['TEX', 28, '2016-08-05T20:10:00', 63],
#  ['TEX', 28, '2016-08-06T19:10:00', 63],
#  ['TEX', 28, '2016-08-07T14:10:00', 63],
#  ['MIN', 20, '2016-08-08T20:10:00', 14],
#  ['MIN', 20, '2016-08-09T20:10:00', 14],
#  ['MIN', 20, '2016-08-10T20:10:00', 14],
#  ['MIN', 20, '2016-08-11T19:10:00', 14],
#  ['MIN', 20, '2016-08-11T13:10:00', 14],
#  ['TOR', 3, '2016-08-12T19:07:00', 42],
#  ['TOR', 3, '2016-08-13T13:07:00', 42],
#  ['TOR', 3, '2016-08-14T13:07:00', 42],
#  ['STL', 31, '2016-08-16T20:10:00', 63],
#  ['STL', 31, '2016-08-17T14:10:00', 63],
#  ['BAL', 19, '2016-08-18T19:05:00', 22],
#  ['BAL', 19, '2016-08-19T19:05:00', 22],
#  ['BAL', 19, '2016-08-20T19:05:00', 22],
#  ['BAL', 19, '2016-08-21T13:35:00', 22],
#  ['PIT', 4, '2016-08-22T19:05:00', 29],
#  ['PIT', 4, '2016-08-23T19:05:00', 29],
#  ['PIT', 4, '2016-08-24T12:35:00', 29],
#  ['TB', 11, '2016-08-26T20:10:00', 63],
#  ['TB', 11, '2016-08-27T19:10:00', 63],
#  ['TB', 11, '2016-08-28T14:10:00', 63],
#  ['OAK', 24, '2016-08-29T20:10:00', 63],
#  ['OAK', 24, '2016-08-30T20:10:00', 63],
#  ['OAK', 24, '2016-08-31T14:10:00', 63],
#  ['TEX', 28, '2016-09-02T20:05:00', 21],
#  ['TEX', 28, '2016-09-03T16:05:00', 21],
#  ['TEX', 28, '2016-09-04T15:05:00', 21],
#  ['CLE', 10, '2016-09-05T19:10:00', 10],
#  ['CLE', 10, '2016-09-06T19:10:00', 10],
#  ['CLE', 10, '2016-09-07T19:10:00', 10],
#  ['CLE', 10, '2016-09-08T12:10:00', 10],
#  ['CHC', 9, '2016-09-09T20:10:00', 63],
#  ['CHC', 9, '2016-09-10T13:05:00', 63],
#  ['CHC', 9, '2016-09-11T20:05:00', 63],
#  ['TEX', 28, '2016-09-12T20:10:00', 63],
#  ['TEX', 28, '2016-09-13T20:10:00', 63],
#  ['TEX', 28, '2016-09-14T20:10:00', 63],
#  ['SEA', 13, '2016-09-16T22:10:00', 65],
#  ['SEA', 13, '2016-09-17T21:10:00', 65],
#  ['SEA', 13, '2016-09-18T16:10:00', 65],
#  ['OAK', 24, '2016-09-19T22:05:00', 23],
#  ['OAK', 24, '2016-09-20T22:05:00', 23],
#  ['OAK', 24, '2016-09-21T15:35:00', 23],
#  ['LAA', 21, '2016-09-22T20:10:00', 63],
#  ['LAA', 21, '2016-09-23T20:10:00', 63],
#  ['LAA', 21, '2016-09-24T19:10:00', 63],
#  ['LAA', 21, '2016-09-25T14:10:00', 63],
#  ['SEA', 13, '2016-09-26T20:10:00', 63],
#  ['SEA', 13, '2016-09-27T20:10:00', 63],
#  ['SEA', 13, '2016-09-28T14:10:00', 63],
#  ['LAA', 21, '2016-09-30T22:05:00', 28],
#  ['LAA', 21, '2016-10-01T21:05:00', 28],
#  ['LAA', 21, '2016-10-02T15:05:00', 28]]

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'ff202b724b714dc3aa66aa292a78b964',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/mlb/stats/json/AllTeams?%s" % params, "{body}", headers)
    response = conn.getresponse()
    team = response.read()
    # print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
team_detail = json.loads(team)

# %%
with open('MLB_v3_Stats_Teams_Active.json', 'w') as out:
    json.dump(team_detail, out)

# %%
with open('MLB_v3_Stats_Teams_Active.json', 'r') as out:
    team_detail=json.load(out)

team_detail
# Out:
# [{'Active': True,
#   'City': 'Los Angeles',
#   'Division': 'West',
#   'GlobalTeamID': 10000001,
#   'Key': 'LAD',
#   'League': 'NL',
#   'Name': 'Dodgers',
#   'PrimaryColor': '005A9C',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'FFFFFF',
#   'StadiumID': 31,
#   'TeamID': 1,
#   'TertiaryColor': 'EF3E42',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/2/20/Los_Angeles_Dodgers_Logo.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/f6/LA_Dodgers.svg'},
#  {'Active': True,
#   'City': 'Cincinnati',
#   'Division': 'Central',
#   'GlobalTeamID': 10000002,
#   'Key': 'CIN',
#   'League': 'NL',
#   'Name': 'Reds',
#   'PrimaryColor': 'C6011F',
#   'QuaternaryColor': '',
#   'SecondaryColor': '000000',
#   'StadiumID': 64,
#   'TeamID': 2,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Cincinnati_Reds_Logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/7/71/Cincinnati_Reds_Cap_Insignia.svg'},
#  {'Active': True,
#   'City': 'Toronto',
#   'Division': 'East',
#   'GlobalTeamID': 10000003,
#   'Key': 'TOR',
#   'League': 'AL',
#   'Name': 'Blue Jays',
#   'PrimaryColor': '134A8E',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': '1D2D5C',
#   'StadiumID': 42,
#   'TeamID': 3,
#   'TertiaryColor': 'E8291C',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/b/ba/Toronto_Blue_Jays_logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/1/11/TorontoBlueJays2012cap.png'},
#  {'Active': True,
#   'City': 'Pittsburgh',
#   'Division': 'Central',
#   'GlobalTeamID': 10000004,
#   'Key': 'PIT',
#   'League': 'NL',
#   'Name': 'Pirates',
#   'PrimaryColor': '000000',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'FDB827',
#   'StadiumID': 29,
#   'TeamID': 4,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/8/81/Pittsburgh_Pirates_logo_2014.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/2/24/Pittsburgh_Pirates_Cap_Insignia.svg'},
#  {'Active': True,
#   'City': 'Kansas City',
#   'Division': 'Central',
#   'GlobalTeamID': 10000005,
#   'Key': 'KC',
#   'League': 'AL',
#   'Name': 'Royals',
#   'PrimaryColor': '004687',
#   'QuaternaryColor': '7AB2DD',
#   'SecondaryColor': 'C09A5B',
#   'StadiumID': 33,
#   'TeamID': 5,
#   'TertiaryColor': '000000',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/1/1c/Kansas_City_Royals.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/8/88/Kansas_City_Royals_Insignia.svg'},
#  {'Active': False,
#   'City': '',
#   'Division': '',
#   'GlobalTeamID': 10000006,
#   'Key': 'RETIRED',
#   'League': '',
#   'Name': 'Retired',
#   'PrimaryColor': None,
#   'QuaternaryColor': None,
#   'SecondaryColor': None,
#   'StadiumID': None,
#   'TeamID': 6,
#   'TertiaryColor': None,
#   'WikipediaLogoUrl': None,
#   'WikipediaWordMarkUrl': None},
#  {'Active': False,
#   'City': 'National League',
#   'Division': 'NL',
#   'GlobalTeamID': 10000007,
#   'Key': 'NL',
#   'League': 'NL',
#   'Name': 'All Stars',
#   'PrimaryColor': None,
#   'QuaternaryColor': None,
#   'SecondaryColor': None,
#   'StadiumID': None,
#   'TeamID': 7,
#   'TertiaryColor': None,
#   'WikipediaLogoUrl': None,
#   'WikipediaWordMarkUrl': None},
#  {'Active': False,
#   'City': '',
#   'Division': '',
#   'GlobalTeamID': 10000008,
#   'Key': 'NOTEAM',
#   'League': '',
#   'Name': 'Unknown Team',
#   'PrimaryColor': None,
#   'QuaternaryColor': None,
#   'SecondaryColor': None,
#   'StadiumID': 12,
#   'TeamID': 8,
#   'TertiaryColor': None,
#   'WikipediaLogoUrl': None,
#   'WikipediaWordMarkUrl': None},
#  {'Active': True,
#   'City': 'Chicago',
#   'Division': 'Central',
#   'GlobalTeamID': 10000009,
#   'Key': 'CHC',
#   'League': 'NL',
#   'Name': 'Cubs',
#   'PrimaryColor': '0E3386',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'CC3433',
#   'StadiumID': 27,
#   'TeamID': 9,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Chicago_Cubs_logo.svg/99px-Chicago_Cubs_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/8/89/Chicago_Cubs_Cap_Insignia.svg'},
#  {'Active': True,
#   'City': 'Cleveland',
#   'Division': 'Central',
#   'GlobalTeamID': 10000010,
#   'Key': 'CLE',
#   'League': 'AL',
#   'Name': 'Indians',
#   'PrimaryColor': 'E31937',
#   'QuaternaryColor': '',
#   'SecondaryColor': '002B5C',
#   'StadiumID': 10,
#   'TeamID': 10,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/e/e5/Indians_Logo_-_2014_Season.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/0d/Cleveland_Indians_cap_logo.svg/547px-Cleveland_Indians_cap_logo.svg.png'},
#  {'Active': True,
#   'City': 'Tampa Bay',
#   'Division': 'East',
#   'GlobalTeamID': 10000011,
#   'Key': 'TB',
#   'League': 'AL',
#   'Name': 'Rays',
#   'PrimaryColor': '092C5C',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': '8FBCE6',
#   'StadiumID': 18,
#   'TeamID': 11,
#   'TertiaryColor': 'F5D130',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/c/c6/Tampa_Bay_Rays.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/e/e2/ALE-TB-Insignia.png'},
#  {'Active': True,
#   'City': 'Philadelphia',
#   'Division': 'East',
#   'GlobalTeamID': 10000012,
#   'Key': 'PHI',
#   'League': 'NL',
#   'Name': 'Phillies',
#   'PrimaryColor': 'E81828',
#   'QuaternaryColor': '',
#   'SecondaryColor': '284898',
#   'StadiumID': 51,
#   'TeamID': 12,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/8/84/Philadelphia_Phillies.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Philadelphia_Phillies_Insignia.svg/100px-Philadelphia_Phillies_Insignia.svg.png'},
#  {'Active': True,
#   'City': 'Seattle',
#   'Division': 'West',
#   'GlobalTeamID': 10000013,
#   'Key': 'SEA',
#   'League': 'AL',
#   'Name': 'Mariners',
#   'PrimaryColor': '0C2C56',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': 'C4CED4',
#   'StadiumID': 65,
#   'TeamID': 13,
#   'TertiaryColor': '005C5C',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/b/b0/Seattle_Mariners_logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/8/8a/Seattle_Mariners_Insignia.svg'},
#  {'Active': True,
#   'City': 'Arizona',
#   'Division': 'West',
#   'GlobalTeamID': 10000014,
#   'Key': 'ARI',
#   'League': 'NL',
#   'Name': 'Diamondbacks',
#   'PrimaryColor': 'A71930',
#   'QuaternaryColor': '33CCFF',
#   'SecondaryColor': 'E3D4AD',
#   'StadiumID': 54,
#   'TeamID': 14,
#   'TertiaryColor': '000000',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/8/89/Arizona_Diamondbacks_logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/c/ce/DbacksCapLogo.png'},
#  {'Active': True,
#   'City': 'San Francisco',
#   'Division': 'West',
#   'GlobalTeamID': 10000015,
#   'Key': 'SF',
#   'League': 'NL',
#   'Name': 'Giants',
#   'PrimaryColor': 'FD5A1E',
#   'QuaternaryColor': 'E6D8AF',
#   'SecondaryColor': '000000',
#   'StadiumID': 13,
#   'TeamID': 15,
#   'TertiaryColor': '8B6F4E',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/5/58/San_Francisco_Giants_Logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/San_Francisco_Giants_Cap_Insignia.svg/97px-San_Francisco_Giants_Cap_Insignia.svg.png'},
#  {'Active': True,
#   'City': 'Chicago',
#   'Division': 'Central',
#   'GlobalTeamID': 10000016,
#   'Key': 'CHW',
#   'League': 'AL',
#   'Name': 'White Sox',
#   'PrimaryColor': '000000',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'C4CED4',
#   'StadiumID': 25,
#   'TeamID': 16,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Chicago_White_Sox.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/d/d6/Chicago_White_Sox_Insignia.svg'},
#  {'Active': True,
#   'City': 'Detroit',
#   'Division': 'Central',
#   'GlobalTeamID': 10000017,
#   'Key': 'DET',
#   'League': 'AL',
#   'Name': 'Tigers',
#   'PrimaryColor': '0C2C56',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'FF6600',
#   'StadiumID': 62,
#   'TeamID': 17,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/2/20/Detroit_tigers_textlogo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/9/94/Detroit_Tigers_Insignia.svg'},
#  {'Active': True,
#   'City': 'New York',
#   'Division': 'East',
#   'GlobalTeamID': 10000018,
#   'Key': 'NYM',
#   'League': 'NL',
#   'Name': 'Mets',
#   'PrimaryColor': '002D72',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'FF5910',
#   'StadiumID': 8,
#   'TeamID': 18,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/7/7b/New_York_Mets.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/7/7b/New_York_Mets.svg'},
#  {'Active': True,
#   'City': 'Baltimore',
#   'Division': 'East',
#   'GlobalTeamID': 10000019,
#   'Key': 'BAL',
#   'League': 'AL',
#   'Name': 'Orioles',
#   'PrimaryColor': 'DF4601',
#   'QuaternaryColor': '',
#   'SecondaryColor': '000000',
#   'StadiumID': 22,
#   'TeamID': 19,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/e/ef/Baltimore_Orioles_logo.svg/200px-Baltimore_Orioles_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/75/Baltimore_Orioles_cap.svg/105px-Baltimore_Orioles_cap.svg.png'},
#  {'Active': True,
#   'City': 'Minnesota',
#   'Division': 'Central',
#   'GlobalTeamID': 10000020,
#   'Key': 'MIN',
#   'League': 'AL',
#   'Name': 'Twins',
#   'PrimaryColor': '002B5C',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': 'D31145',
#   'StadiumID': 14,
#   'TeamID': 20,
#   'TertiaryColor': 'CFAB7A',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/6/61/MinnesotaTwins.PNG',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/2/2f/Minnesota_Twins_Insignia.svg'},
#  {'Active': True,
#   'City': 'Los Angeles',
#   'Division': 'West',
#   'GlobalTeamID': 10000021,
#   'Key': 'LAA',
#   'League': 'AL',
#   'Name': 'Angels',
#   'PrimaryColor': 'BA0021',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': '003263',
#   'StadiumID': 28,
#   'TeamID': 21,
#   'TertiaryColor': 'C4CED4',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/8/8b/Los_Angeles_Angels_of_Anaheim.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/7/79/Los_Angeles_Angels_of_Anaheim_Insignia.svg'},
#  {'Active': True,
#   'City': 'Miami',
#   'Division': 'East',
#   'GlobalTeamID': 10000022,
#   'Key': 'MIA',
#   'League': 'NL',
#   'Name': 'Marlins',
#   'PrimaryColor': '000000',
#   'QuaternaryColor': 'FFD100',
#   'SecondaryColor': 'FF6600',
#   'StadiumID': 57,
#   'TeamID': 22,
#   'TertiaryColor': '0077C8',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f0/Miami_Marlins_logo.svg/99px-Miami_Marlins_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/4/47/MiamiMarlinscap.PNG'},
#  {'Active': True,
#   'City': 'Colorado',
#   'Division': 'West',
#   'GlobalTeamID': 10000023,
#   'Key': 'COL',
#   'League': 'NL',
#   'Name': 'Rockies',
#   'PrimaryColor': '33006F',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': '000000',
#   'StadiumID': 44,
#   'TeamID': 23,
#   'TertiaryColor': 'C4CED4',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/31/Colorado_Rockies_logo.svg/83px-Colorado_Rockies_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Colorado_Rockies_Cap_Insignia.svg/97px-Colorado_Rockies_Cap_Insignia.svg.png'},
#  {'Active': True,
#   'City': 'Oakland',
#   'Division': 'West',
#   'GlobalTeamID': 10000024,
#   'Key': 'OAK',
#   'League': 'AL',
#   'Name': 'Athletics',
#   'PrimaryColor': '003831',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'EFB21E',
#   'StadiumID': 23,
#   'TeamID': 24,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Oakland_A%27s_logo.svg/150px-Oakland_A%27s_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/3/3a/Oakland_Athletics_cap_logo.png'},
#  {'Active': True,
#   'City': 'Boston',
#   'Division': 'East',
#   'GlobalTeamID': 10000025,
#   'Key': 'BOS',
#   'League': 'AL',
#   'Name': 'Red Sox',
#   'PrimaryColor': 'BD3039',
#   'QuaternaryColor': '',
#   'SecondaryColor': '0D2B56',
#   'StadiumID': 50,
#   'TeamID': 25,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/6/6d/RedSoxPrimary_HangingSocks.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/2/21/Bosb.png'},
#  {'Active': True,
#   'City': 'Atlanta',
#   'Division': 'East',
#   'GlobalTeamID': 10000026,
#   'Key': 'ATL',
#   'League': 'NL',
#   'Name': 'Braves',
#   'PrimaryColor': '13274F',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'CE1141',
#   'StadiumID': 68,
#   'TeamID': 26,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/f/f2/Atlanta_Braves.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Atlanta_Braves_Insignia.svg'},
#  {'Active': False,
#   'City': 'American League',
#   'Division': 'AL',
#   'GlobalTeamID': 10000027,
#   'Key': 'AL',
#   'League': 'AL',
#   'Name': 'All Stars',
#   'PrimaryColor': None,
#   'QuaternaryColor': None,
#   'SecondaryColor': None,
#   'StadiumID': None,
#   'TeamID': 27,
#   'TertiaryColor': None,
#   'WikipediaLogoUrl': None,
#   'WikipediaWordMarkUrl': None},
#  {'Active': True,
#   'City': 'Texas',
#   'Division': 'West',
#   'GlobalTeamID': 10000028,
#   'Key': 'TEX',
#   'League': 'AL',
#   'Name': 'Rangers',
#   'PrimaryColor': '003278',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'C0111F',
#   'StadiumID': 21,
#   'TeamID': 28,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/4/41/Texas_Rangers.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/e/e2/Texas_Rangers_Insignia.svg'},
#  {'Active': True,
#   'City': 'New York',
#   'Division': 'East',
#   'GlobalTeamID': 10000029,
#   'Key': 'NYY',
#   'League': 'AL',
#   'Name': 'Yankees',
#   'PrimaryColor': '132448',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'C4CED4',
#   'StadiumID': 35,
#   'TeamID': 29,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/2/25/NewYorkYankees_PrimaryLogo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/7/70/NewYorkYankees_caplogo.svg'},
#  {'Active': True,
#   'City': 'Houston',
#   'Division': 'West',
#   'GlobalTeamID': 10000030,
#   'Key': 'HOU',
#   'League': 'AL',
#   'Name': 'Astros',
#   'PrimaryColor': '002D62',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'EB6E1F',
#   'StadiumID': 63,
#   'TeamID': 30,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/6/6b/Houston-Astros-Logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/f6/Houston_Astros_cap_logo.svg'},
#  {'Active': True,
#   'City': 'St. Louis',
#   'Division': 'Central',
#   'GlobalTeamID': 10000031,
#   'Key': 'STL',
#   'League': 'NL',
#   'Name': 'Cardinals',
#   'PrimaryColor': 'C41E3A',
#   'QuaternaryColor': 'FFFFFF',
#   'SecondaryColor': '000066',
#   'StadiumID': 41,
#   'TeamID': 31,
#   'TertiaryColor': 'FEDB00',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/thumb/9/9d/St._Louis_Cardinals_logo.svg/105px-St._Louis_Cardinals_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/e/ee/St_Louis_Cardinals_Cap_Insignia.svg'},
#  {'Active': True,
#   'City': 'Milwaukee',
#   'Division': 'Central',
#   'GlobalTeamID': 10000032,
#   'Key': 'MIL',
#   'League': 'NL',
#   'Name': 'Brewers',
#   'PrimaryColor': '0A2351',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'B6922E',
#   'StadiumID': 19,
#   'TeamID': 32,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/1/11/Milwaukee_Brewers_Logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/en/4/4a/MilwaukeeBrewers_caplogo.svg'},
#  {'Active': True,
#   'City': 'San Diego',
#   'Division': 'West',
#   'GlobalTeamID': 10000033,
#   'Key': 'SD',
#   'League': 'NL',
#   'Name': 'Padres',
#   'PrimaryColor': '05143F',
#   'QuaternaryColor': '',
#   'SecondaryColor': 'FFFFFF',
#   'StadiumID': 1,
#   'TeamID': 33,
#   'TertiaryColor': '',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/SDPadres_logo.svg/75px-SDPadres_logo.svg.png',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f2/San_Diego_Padres_logotype.svg/100px-San_Diego_Padres_logotype.svg.png'},
#  {'Active': False,
#   'City': '',
#   'Division': '',
#   'GlobalTeamID': 10000034,
#   'Key': 'MINOR',
#   'League': '',
#   'Name': 'Minor League',
#   'PrimaryColor': None,
#   'QuaternaryColor': None,
#   'SecondaryColor': None,
#   'StadiumID': None,
#   'TeamID': 34,
#   'TertiaryColor': None,
#   'WikipediaLogoUrl': None,
#   'WikipediaWordMarkUrl': None},
#  {'Active': True,
#   'City': 'Washington',
#   'Division': 'East',
#   'GlobalTeamID': 10000035,
#   'Key': 'WSH',
#   'League': 'NL',
#   'Name': 'Nationals',
#   'PrimaryColor': 'AB0003',
#   'QuaternaryColor': '',
#   'SecondaryColor': '11225B',
#   'StadiumID': 53,
#   'TeamID': 35,
#   'TertiaryColor': 'FFFFFF',
#   'WikipediaLogoUrl': 'https://upload.wikimedia.org/wikipedia/en/a/a3/Washington_Nationals_logo.svg',
#   'WikipediaWordMarkUrl': 'https://upload.wikimedia.org/wikipedia/commons/e/e5/Washington_Nationals_Cap_Insig.svg'}]

# %%
team_lookup = {}
for item in team_detail:
    #print ({item['TeamID']: item['City'] + ' ' +item['Name']})
    ID = item['TeamID']
    Name = item['City'] + ' ' +item['Name']
    team_lookup[ID] = Name
    
#team_lookup

# %%
for t in game:
    if t[1] in team_lookup:
        t.append(team_lookup[t[1]])

# %%
headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'ff202b724b714dc3aa66aa292a78b964',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/mlb/stats/json/Stadiums?%s" % params, "{body}", headers)
    response = conn.getresponse()
    stadiums = response.read()
    # print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
with open('MLB_v3_Stats_stadium.json', 'w') as o:
    json.dump(stadium, o)

# %%
with open('MLB_v3_Stats_stadium.json', 'r') as o:
    stadium = json.load(o)
    
#stadium = json.loads(stadiums)
stadium
# Out:
# [{'Active': True,
#   'Altitude': 14,
#   'Capacity': 41164,
#   'CenterField': 396,
#   'City': 'San Diego',
#   'Country': 'USA',
#   'GeoLat': 32.70771,
#   'GeoLong': -117.157097,
#   'HomePlateDirection': 180,
#   'LeftCenterField': 367,
#   'LeftField': 334,
#   'MidLeftCenterField': 402,
#   'MidLeftField': 351,
#   'MidRightCenterField': 403,
#   'MidRightField': 351,
#   'Name': 'PETCO Park',
#   'RightCenterField': 378,
#   'RightField': 322,
#   'StadiumID': 1,
#   'State': 'CA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 939,
#   'Capacity': 49586,
#   'CenterField': 401,
#   'City': 'Atlanta',
#   'Country': 'USA',
#   'GeoLat': 33.734805,
#   'GeoLong': -84.389996,
#   'HomePlateDirection': 150,
#   'LeftCenterField': 380,
#   'LeftField': 335,
#   'MidLeftCenterField': 394,
#   'MidLeftField': 360,
#   'MidRightCenterField': 394,
#   'MidRightField': 358,
#   'Name': 'Turner Field',
#   'RightCenterField': 390,
#   'RightField': 330,
#   'StadiumID': 2,
#   'State': 'GA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Salt River Fields at Talking Stick',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 3,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Cubs Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 4,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'JetBlue Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 5,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Hammond Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 6,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Peoria Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 7,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 13,
#   'Capacity': 41922,
#   'CenterField': 408,
#   'City': 'New York',
#   'Country': 'USA',
#   'GeoLat': 40.756337,
#   'GeoLong': -73.846043,
#   'HomePlateDirection': 165,
#   'LeftCenterField': 384,
#   'LeftField': 335,
#   'MidLeftCenterField': 394,
#   'MidLeftField': 371,
#   'MidRightCenterField': 415,
#   'MidRightField': 372,
#   'Name': 'Citi Field',
#   'RightCenterField': 378,
#   'RightField': 330,
#   'StadiumID': 8,
#   'State': 'NY',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'State Mutual Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 9,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 673,
#   'Capacity': 37675,
#   'CenterField': 405,
#   'City': 'Cleveland',
#   'Country': 'USA',
#   'GeoLat': 41.496192,
#   'GeoLong': -81.685238,
#   'HomePlateDirection': 180,
#   'LeftCenterField': 368,
#   'LeftField': 325,
#   'MidLeftCenterField': 385,
#   'MidLeftField': 369,
#   'MidRightCenterField': 388,
#   'MidRightField': 364,
#   'Name': 'Progressive Field',
#   'RightCenterField': 375,
#   'RightField': 325,
#   'StadiumID': 10,
#   'State': 'OH',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'NL City',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 11,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'TBD',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 12,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 8,
#   'Capacity': 41915,
#   'CenterField': 399,
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'GeoLat': 37.778473,
#   'GeoLong': -122.389595,
#   'HomePlateDirection': 90,
#   'LeftCenterField': 382,
#   'LeftField': 339,
#   'MidLeftCenterField': 389,
#   'MidLeftField': 346,
#   'MidRightCenterField': 399,
#   'MidRightField': 368,
#   'Name': 'AT&amp;T Park',
#   'RightCenterField': 421,
#   'RightField': 309,
#   'StadiumID': 13,
#   'State': 'CA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 840,
#   'Capacity': 39021,
#   'CenterField': 404,
#   'City': 'Minneapolis',
#   'Country': 'USA',
#   'GeoLat': 44.981713,
#   'GeoLong': -93.277347,
#   'HomePlateDirection': 105,
#   'LeftCenterField': 377,
#   'LeftField': 339,
#   'MidLeftCenterField': 390,
#   'MidLeftField': 355,
#   'MidRightCenterField': 392,
#   'MidRightField': 344,
#   'Name': 'Target Field',
#   'RightCenterField': 367,
#   'RightField': 328,
#   'StadiumID': 14,
#   'State': 'MN',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'McKechnie Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 15,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Louisville Slugger Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 16,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Champion Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 17,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 41,
#   'Capacity': 31042,
#   'CenterField': 404,
#   'City': 'St. Petersburg',
#   'Country': 'USA',
#   'GeoLat': 27.76816,
#   'GeoLong': -82.653465,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 370,
#   'LeftField': 315,
#   'MidLeftCenterField': 410,
#   'MidLeftField': 354,
#   'MidRightCenterField': 404,
#   'MidRightField': 342,
#   'Name': 'Tropicana Field',
#   'RightCenterField': 370,
#   'RightField': 322,
#   'StadiumID': 18,
#   'State': 'FL',
#   'Surface': 'AstroTurf',
#   'Type': 'Dome'},
#  {'Active': True,
#   'Altitude': 602,
#   'Capacity': 41900,
#   'CenterField': 400,
#   'City': 'Milwaukee',
#   'Country': 'USA',
#   'GeoLat': 43.027982,
#   'GeoLong': -87.971165,
#   'HomePlateDirection': 45,
#   'LeftCenterField': 370,
#   'LeftField': 344,
#   'MidLeftCenterField': 379,
#   'MidLeftField': 359,
#   'MidRightCenterField': 386,
#   'MidRightField': 354,
#   'Name': 'Miller Park',
#   'RightCenterField': 374,
#   'RightField': 345,
#   'StadiumID': 19,
#   'State': 'WI',
#   'Surface': 'Grass',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'AutoZone Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 20,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 549,
#   'Capacity': 48114,
#   'CenterField': 400,
#   'City': 'Arlington',
#   'Country': 'USA',
#   'GeoLat': 32.751147,
#   'GeoLong': -97.082454,
#   'HomePlateDirection': 45,
#   'LeftCenterField': 390,
#   'LeftField': 354,
#   'MidLeftCenterField': 406,
#   'MidLeftField': 357,
#   'MidRightCenterField': 407,
#   'MidRightField': 356,
#   'Name': 'Globe Life Park in Arlington',
#   'RightCenterField': 379,
#   'RightField': 349,
#   'StadiumID': 21,
#   'State': 'TX',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 35,
#   'Capacity': 45971,
#   'CenterField': 410,
#   'City': 'Baltimore',
#   'Country': 'USA',
#   'GeoLat': 39.283964,
#   'GeoLong': -76.621618,
#   'HomePlateDirection': 150,
#   'LeftCenterField': 364,
#   'LeftField': 333,
#   'MidLeftCenterField': 378,
#   'MidLeftField': 368,
#   'MidRightCenterField': 400,
#   'MidRightField': 341,
#   'Name': 'Oriole Park at Camden Yards',
#   'RightCenterField': 373,
#   'RightField': 318,
#   'StadiumID': 22,
#   'State': 'MD',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 0,
#   'Capacity': 35067,
#   'CenterField': 400,
#   'City': 'Oakland',
#   'Country': 'USA',
#   'GeoLat': 37.751605,
#   'GeoLong': -122.200523,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 362,
#   'LeftField': 330,
#   'MidLeftCenterField': 388,
#   'MidLeftField': 367,
#   'MidRightCenterField': 388,
#   'MidRightField': 367,
#   'Name': 'O.co Coliseum',
#   'RightCenterField': 362,
#   'RightField': 330,
#   'StadiumID': 23,
#   'State': 'CA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Florida Auto Exchange Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 24,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 594,
#   'Capacity': 40615,
#   'CenterField': 400,
#   'City': 'Chicago',
#   'Country': 'USA',
#   'GeoLat': 41.829908,
#   'GeoLong': -87.63354,
#   'HomePlateDirection': 45,
#   'LeftCenterField': 377,
#   'LeftField': 330,
#   'MidLeftCenterField': 385,
#   'MidLeftField': 365,
#   'MidRightCenterField': 385,
#   'MidRightField': 365,
#   'Name': 'U.S. Cellular Field',
#   'RightCenterField': 372,
#   'RightField': 335,
#   'StadiumID': 25,
#   'State': 'IL',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Olympic Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 26,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 599,
#   'Capacity': 40929,
#   'CenterField': 400,
#   'City': 'Chicago',
#   'Country': 'USA',
#   'GeoLat': 41.947856,
#   'GeoLong': -87.655887,
#   'HomePlateDirection': 150,
#   'LeftCenterField': 368,
#   'LeftField': 355,
#   'MidLeftCenterField': 391,
#   'MidLeftField': 356,
#   'MidRightCenterField': 397,
#   'MidRightField': 356,
#   'Name': 'Wrigley Field',
#   'RightCenterField': 368,
#   'RightField': 353,
#   'StadiumID': 27,
#   'State': 'IL',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 154,
#   'Capacity': 43250,
#   'CenterField': 408,
#   'City': 'Anaheim',
#   'Country': 'USA',
#   'GeoLat': 33.799925,
#   'GeoLong': -117.883194,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 376,
#   'LeftField': 330,
#   'MidLeftCenterField': 387,
#   'MidLeftField': 348,
#   'MidRightCenterField': 383,
#   'MidRightField': 359,
#   'Name': 'Angel Stadium of Anaheim',
#   'RightCenterField': 362,
#   'RightField': 330,
#   'StadiumID': 28,
#   'State': 'CA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 724,
#   'Capacity': 38362,
#   'CenterField': 399,
#   'City': 'Pittsburgh',
#   'Country': 'USA',
#   'GeoLat': 40.447307,
#   'GeoLong': -80.006841,
#   'HomePlateDirection': 60,
#   'LeftCenterField': 389,
#   'LeftField': 325,
#   'MidLeftCenterField': 410,
#   'MidLeftField': 370,
#   'MidRightCenterField': 393,
#   'MidRightField': 353,
#   'Name': 'PNC Park',
#   'RightCenterField': 375,
#   'RightField': 320,
#   'StadiumID': 29,
#   'State': 'PA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Tradition Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 30,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 501,
#   'Capacity': 56000,
#   'CenterField': 395,
#   'City': 'Los Angeles',
#   'Country': 'USA',
#   'GeoLat': 34.072724,
#   'GeoLong': -118.240646,
#   'HomePlateDirection': 150,
#   'LeftCenterField': 385,
#   'LeftField': 330,
#   'MidLeftCenterField': 390,
#   'MidLeftField': 380,
#   'MidRightCenterField': 390,
#   'MidRightField': 380,
#   'Name': 'Dodger Stadium',
#   'RightCenterField': 385,
#   'RightField': 330,
#   'StadiumID': 31,
#   'State': 'CA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Tempe Diablo Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 32,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 886,
#   'Capacity': 37903,
#   'CenterField': 410,
#   'City': 'Kansas City',
#   'Country': 'USA',
#   'GeoLat': 39.051098,
#   'GeoLong': -94.481115,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 387,
#   'LeftField': 330,
#   'MidLeftCenterField': 390,
#   'MidLeftField': 351,
#   'MidRightCenterField': 390,
#   'MidRightField': 351,
#   'Name': 'Kauffman Stadium',
#   'RightCenterField': 387,
#   'RightField': 330,
#   'StadiumID': 33,
#   'State': 'MO',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Roger Dean Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 34,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 11,
#   'Capacity': 49642,
#   'CenterField': 408,
#   'City': 'New York',
#   'Country': 'USA',
#   'GeoLat': 40.829327,
#   'GeoLong': -73.927735,
#   'HomePlateDirection': 105,
#   'LeftCenterField': 399,
#   'LeftField': 318,
#   'MidLeftCenterField': 400,
#   'MidLeftField': 357,
#   'MidRightCenterField': 396,
#   'MidRightField': 346,
#   'Name': 'Yankee Stadium',
#   'RightCenterField': 385,
#   'RightField': 314,
#   'StadiumID': 35,
#   'State': 'NY',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Montgomery Riverwalk Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 36,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Harbor Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 37,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Osceola County Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 38,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Bright House Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 39,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Sydney Cricket Ground',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 40,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 438,
#   'Capacity': 43975,
#   'CenterField': 400,
#   'City': 'St. Louis',
#   'Country': 'USA',
#   'GeoLat': 38.622317,
#   'GeoLong': -90.193891,
#   'HomePlateDirection': 120,
#   'LeftCenterField': 390,
#   'LeftField': 336,
#   'MidLeftCenterField': 392,
#   'MidLeftField': 354,
#   'MidRightCenterField': 392,
#   'MidRightField': 354,
#   'Name': 'Busch Stadium',
#   'RightCenterField': 390,
#   'RightField': 335,
#   'StadiumID': 41,
#   'State': 'MO',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 268,
#   'Capacity': 49282,
#   'CenterField': 400,
#   'City': 'Toronto',
#   'Country': 'Canada',
#   'GeoLat': 43.641111,
#   'GeoLong': -79.389675,
#   'HomePlateDirection': 210,
#   'LeftCenterField': 375,
#   'LeftField': 328,
#   'MidLeftCenterField': 391,
#   'MidLeftField': 348,
#   'MidRightCenterField': 391,
#   'MidRightField': 348,
#   'Name': 'Rogers Centre',
#   'RightCenterField': 375,
#   'RightField': 328,
#   'StadiumID': 42,
#   'State': 'ON',
#   'Surface': 'AstroTurf',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Phoenix Municipal Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 43,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 5211,
#   'Capacity': 50398,
#   'CenterField': 415,
#   'City': 'Denver',
#   'Country': 'USA',
#   'GeoLat': 39.755891,
#   'GeoLong': -104.994198,
#   'HomePlateDirection': 180,
#   'LeftCenterField': 390,
#   'LeftField': 347,
#   'MidLeftCenterField': 397,
#   'MidLeftField': 361,
#   'MidRightCenterField': 391,
#   'MidRightField': 365,
#   'Name': 'Coors Field',
#   'RightCenterField': 375,
#   'RightField': 350,
#   'StadiumID': 44,
#   'State': 'CO',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Goodyear Ballpark',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 45,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'AL City',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 46,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Pensacola Bayfront Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 47,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Alamodome',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 48,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Ed Smith Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 49,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 16,
#   'Capacity': 37499,
#   'CenterField': 390,
#   'City': 'Boston',
#   'Country': 'USA',
#   'GeoLat': 42.346619,
#   'GeoLong': -71.096961,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 348,
#   'LeftField': 310,
#   'MidLeftCenterField': 379,
#   'MidLeftField': 320,
#   'MidRightCenterField': 420,
#   'MidRightField': 380,
#   'Name': 'Fenway Park',
#   'RightCenterField': 383,
#   'RightField': 302,
#   'StadiumID': 50,
#   'State': 'MA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 19,
#   'Capacity': 43651,
#   'CenterField': 401,
#   'City': 'Philadelphia',
#   'Country': 'USA',
#   'GeoLat': 39.905547,
#   'GeoLong': -75.166589,
#   'HomePlateDirection': 165,
#   'LeftCenterField': 374,
#   'LeftField': 329,
#   'MidLeftCenterField': 386,
#   'MidLeftField': 349,
#   'MidRightCenterField': 384,
#   'MidRightField': 351,
#   'Name': 'Citizens Bank Park',
#   'RightCenterField': 369,
#   'RightField': 330,
#   'StadiumID': 51,
#   'State': 'PA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Regions Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 52,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 23,
#   'Capacity': 41341,
#   'CenterField': 403,
#   'City': 'Washington',
#   'Country': 'USA',
#   'GeoLat': 38.87301,
#   'GeoLong': -77.007457,
#   'HomePlateDirection': 150,
#   'LeftCenterField': 377,
#   'LeftField': 336,
#   'MidLeftCenterField': 390,
#   'MidLeftField': 351,
#   'MidRightCenterField': 390,
#   'MidRightField': 351,
#   'Name': 'Nationals Park',
#   'RightCenterField': 370,
#   'RightField': 335,
#   'StadiumID': 53,
#   'State': 'DC',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 1059,
#   'Capacity': 48519,
#   'CenterField': 407,
#   'City': 'Phoenix',
#   'Country': 'USA',
#   'GeoLat': 33.445526,
#   'GeoLong': -112.066721,
#   'HomePlateDirection': 180,
#   'LeftCenterField': 374,
#   'LeftField': 330,
#   'MidLeftCenterField': 413,
#   'MidLeftField': 359,
#   'MidRightCenterField': 413,
#   'MidRightField': 359,
#   'Name': 'Chase Field',
#   'RightCenterField': 374,
#   'RightField': 334,
#   'StadiumID': 54,
#   'State': 'AZ',
#   'Surface': 'Grass',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Scottsdale Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 55,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Surprise Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 56,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 6,
#   'Capacity': 36742,
#   'CenterField': 422,
#   'City': 'Miami',
#   'Country': 'USA',
#   'GeoLat': 25.778655,
#   'GeoLong': -80.220305,
#   'HomePlateDirection': 105,
#   'LeftCenterField': 386,
#   'LeftField': 344,
#   'MidLeftCenterField': 395,
#   'MidLeftField': 360,
#   'MidRightCenterField': 405,
#   'MidRightField': 360,
#   'Name': 'Marlins Park',
#   'RightCenterField': 392,
#   'RightField': 335,
#   'StadiumID': 57,
#   'State': 'FL',
#   'Surface': 'Grass',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Charlotte Sports Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 58,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Maryvale Baseball Park',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 59,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Space Coast Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 60,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Camelback Ranch',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 61,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 602,
#   'Capacity': 41574,
#   'CenterField': 420,
#   'City': 'Detroit',
#   'Country': 'USA',
#   'GeoLat': 42.339227,
#   'GeoLong': -83.049506,
#   'HomePlateDirection': 30,
#   'LeftCenterField': 402,
#   'LeftField': 345,
#   'MidLeftCenterField': 406,
#   'MidLeftField': 370,
#   'MidRightCenterField': 393,
#   'MidRightField': 350,
#   'Name': 'Comerica Park',
#   'RightCenterField': 365,
#   'RightField': 330,
#   'StadiumID': 62,
#   'State': 'MI',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 20,
#   'Capacity': 41574,
#   'CenterField': 435,
#   'City': 'Houston',
#   'Country': 'USA',
#   'GeoLat': 29.756965,
#   'GeoLong': -95.354824,
#   'HomePlateDirection': 210,
#   'LeftCenterField': 362,
#   'LeftField': 315,
#   'MidLeftCenterField': 410,
#   'MidLeftField': 347,
#   'MidRightCenterField': 393,
#   'MidRightField': 347,
#   'Name': 'Minute Maid Park',
#   'RightCenterField': 373,
#   'RightField': 326,
#   'StadiumID': 63,
#   'State': 'TX',
#   'Surface': 'Grass',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': 489,
#   'Capacity': 42319,
#   'CenterField': 404,
#   'City': 'Cincinnati',
#   'Country': 'USA',
#   'GeoLat': 39.097935,
#   'GeoLong': -84.508158,
#   'HomePlateDirection': 45,
#   'LeftCenterField': 379,
#   'LeftField': 328,
#   'MidLeftCenterField': 391,
#   'MidLeftField': 356,
#   'MidRightCenterField': 391,
#   'MidRightField': 356,
#   'Name': 'Great American Ball Park',
#   'RightCenterField': 370,
#   'RightField': 325,
#   'StadiumID': 64,
#   'State': 'OH',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'},
#  {'Active': True,
#   'Altitude': 17,
#   'Capacity': 47574,
#   'CenterField': 405,
#   'City': 'Seattle',
#   'Country': 'USA',
#   'GeoLat': 47.591358,
#   'GeoLong': -122.332283,
#   'HomePlateDirection': 135,
#   'LeftCenterField': 390,
#   'LeftField': 331,
#   'MidLeftCenterField': 399,
#   'MidLeftField': 358,
#   'MidRightCenterField': 391,
#   'MidRightField': 353,
#   'Name': 'Safeco Field',
#   'RightCenterField': 387,
#   'RightField': 327,
#   'StadiumID': 65,
#   'State': 'WA',
#   'Surface': 'Grass',
#   'Type': 'RetractableDome'},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'George M. Steinbrenner Field',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 66,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': None,
#   'Capacity': None,
#   'CenterField': None,
#   'City': None,
#   'Country': None,
#   'GeoLat': None,
#   'GeoLong': None,
#   'HomePlateDirection': None,
#   'LeftCenterField': None,
#   'LeftField': None,
#   'MidLeftCenterField': None,
#   'MidLeftField': None,
#   'MidRightCenterField': None,
#   'MidRightField': None,
#   'Name': 'Joker Marchant Stadium',
#   'RightCenterField': None,
#   'RightField': None,
#   'StadiumID': 67,
#   'State': None,
#   'Surface': None,
#   'Type': None},
#  {'Active': True,
#   'Altitude': 1050,
#   'Capacity': 41149,
#   'CenterField': 400,
#   'City': 'Atlanta',
#   'Country': 'USA',
#   'GeoLat': 33.890166,
#   'GeoLong': -84.467724,
#   'HomePlateDirection': 15,
#   'LeftCenterField': 385,
#   'LeftField': 335,
#   'MidLeftCenterField': 402,
#   'MidLeftField': 375,
#   'MidRightCenterField': 402,
#   'MidRightField': 350,
#   'Name': 'SunTrust Park',
#   'RightCenterField': 375,
#   'RightField': 325,
#   'StadiumID': 68,
#   'State': 'GA',
#   'Surface': 'Grass',
#   'Type': 'Outdoor'}]

# %%
stadium_address_lookup = {}
stadium_name_lookup = {}
for item in stadium:
    if item['Altitude']  != None:
        #print ({item['TeamID']: item['City'] + ' ' +item['Name']})
        ID = item['StadiumID']
        sta = item['City'] + ', ' +item['State']
        stadium_address_lookup[ID] = sta
        
for item in stadium:
    if item['Altitude']  != None:
        #print ({item['TeamID']: item['City'] + ' ' +item['Name']})
        ID = item['StadiumID']
        sta = item['Name']
        stadium_name_lookup[ID] = sta

# %%
stadium_name_lookup
# Out:
# {1: 'PETCO Park',
#  2: 'Turner Field',
#  8: 'Citi Field',
#  10: 'Progressive Field',
#  13: 'AT&amp;T Park',
#  14: 'Target Field',
#  18: 'Tropicana Field',
#  19: 'Miller Park',
#  21: 'Globe Life Park in Arlington',
#  22: 'Oriole Park at Camden Yards',
#  23: 'O.co Coliseum',
#  25: 'U.S. Cellular Field',
#  27: 'Wrigley Field',
#  28: 'Angel Stadium of Anaheim',
#  29: 'PNC Park',
#  31: 'Dodger Stadium',
#  33: 'Kauffman Stadium',
#  35: 'Yankee Stadium',
#  41: 'Busch Stadium',
#  42: 'Rogers Centre',
#  44: 'Coors Field',
#  50: 'Fenway Park',
#  51: 'Citizens Bank Park',
#  53: 'Nationals Park',
#  54: 'Chase Field',
#  57: 'Marlins Park',
#  62: 'Comerica Park',
#  63: 'Minute Maid Park',
#  64: 'Great American Ball Park',
#  65: 'Safeco Field',
#  68: 'SunTrust Park'}

# %%
for t in game:
    if t[3] in stadium_address_lookup:
        t.append(stadium_address_lookup[t[3]])
        t.append(stadium_name_lookup[t[3]])

# %%
 # <opponent Team Name> <game date> <stadium name> <city>, <state>
HOU_schedule_list = []
for t in game:
    game_date = t[2][:(t[2].find('T'))]
    game_team = t[4]
    sta_name = t[6]
    location = t[5]
    Hou = [game_team, game_date, sta_name, location]
    HOU_schedule_list.append(Hou)
colname = ['Opponent Team Name', 'Game Date', 'Stadium Name', 'Location']
HOU_schedule = pd.DataFrame(HOU_schedule_list, columns=colname)

# %%
# HOU_schedule
HOU_schedule.to_csv('Answer_6.csv', sep=',',index_label=True)

# %%
HOU_schedule
# Out:
#      Opponent Team Name   Game Date                  Stadium Name  \
# 0      New York Yankees  2016-04-04                Yankee Stadium
# 1      New York Yankees  2016-04-05                Yankee Stadium
# 2      New York Yankees  2016-04-06                Yankee Stadium
# 3      New York Yankees  2016-04-07                Yankee Stadium
# 4     Milwaukee Brewers  2016-04-08                   Miller Park
# 5     Milwaukee Brewers  2016-04-09                   Miller Park
# 6     Milwaukee Brewers  2016-04-10                   Miller Park
# 7    Kansas City Royals  2016-04-11              Minute Maid Park
# 8    Kansas City Royals  2016-04-12              Minute Maid Park
# 9    Kansas City Royals  2016-04-13              Minute Maid Park
# 10   Kansas City Royals  2016-04-14              Minute Maid Park
# 11       Detroit Tigers  2016-04-15              Minute Maid Park
# 12       Detroit Tigers  2016-04-16              Minute Maid Park
# 13       Detroit Tigers  2016-04-17              Minute Maid Park
# 14        Texas Rangers  2016-04-19  Globe Life Park in Arlington
# 15        Texas Rangers  2016-04-20  Globe Life Park in Arlington
# 16        Texas Rangers  2016-04-21  Globe Life Park in Arlington
# 17       Boston Red Sox  2016-04-22              Minute Maid Park
# 18       Boston Red Sox  2016-04-23              Minute Maid Park
# 19       Boston Red Sox  2016-04-24              Minute Maid Park
# 20     Seattle Mariners  2016-04-25                  Safeco Field
# 21     Seattle Mariners  2016-04-26                  Safeco Field
# 22     Seattle Mariners  2016-04-27                  Safeco Field
# 23    Oakland Athletics  2016-04-29                 O.co Coliseum
# 24    Oakland Athletics  2016-04-30                 O.co Coliseum
# 25    Oakland Athletics  2016-05-01                 O.co Coliseum
# 26      Minnesota Twins  2016-05-02              Minute Maid Park
# 27      Minnesota Twins  2016-05-03              Minute Maid Park
# 28      Minnesota Twins  2016-05-04              Minute Maid Park
# 29     Seattle Mariners  2016-05-05              Minute Maid Park
# ..                  ...         ...                           ...
# 134   Oakland Athletics  2016-08-31              Minute Maid Park
# 135       Texas Rangers  2016-09-02  Globe Life Park in Arlington
# 136       Texas Rangers  2016-09-03  Globe Life Park in Arlington
# 137       Texas Rangers  2016-09-04  Globe Life Park in Arlington
# 138   Cleveland Indians  2016-09-05             Progressive Field
# 139   Cleveland Indians  2016-09-06             Progressive Field
# 140   Cleveland Indians  2016-09-07             Progressive Field
# 141   Cleveland Indians  2016-09-08             Progressive Field
# 142        Chicago Cubs  2016-09-09              Minute Maid Park
# 143        Chicago Cubs  2016-09-10              Minute Maid Park
# 144        Chicago Cubs  2016-09-11              Minute Maid Park
# 145       Texas Rangers  2016-09-12              Minute Maid Park
# 146       Texas Rangers  2016-09-13              Minute Maid Park
# 147       Texas Rangers  2016-09-14              Minute Maid Park
# 148    Seattle Mariners  2016-09-16                  Safeco Field
# 149    Seattle Mariners  2016-09-17                  Safeco Field
# 150    Seattle Mariners  2016-09-18                  Safeco Field
# 151   Oakland Athletics  2016-09-19                 O.co Coliseum
# 152   Oakland Athletics  2016-09-20                 O.co Coliseum
# 153   Oakland Athletics  2016-09-21                 O.co Coliseum
# 154  Los Angeles Angels  2016-09-22              Minute Maid Park
# 155  Los Angeles Angels  2016-09-23              Minute Maid Park
# 156  Los Angeles Angels  2016-09-24              Minute Maid Park
# 157  Los Angeles Angels  2016-09-25              Minute Maid Park
# 158    Seattle Mariners  2016-09-26              Minute Maid Park
# 159    Seattle Mariners  2016-09-27              Minute Maid Park
# 160    Seattle Mariners  2016-09-28              Minute Maid Park
# 161  Los Angeles Angels  2016-09-30      Angel Stadium of Anaheim
# 162  Los Angeles Angels  2016-10-01      Angel Stadium of Anaheim
# 163  Los Angeles Angels  2016-10-02      Angel Stadium of Anaheim
#
#           Location
# 0     New York, NY
# 1     New York, NY
# 2     New York, NY
# 3     New York, NY
# 4    Milwaukee, WI
# 5    Milwaukee, WI
# 6    Milwaukee, WI
# 7      Houston, TX
# 8      Houston, TX
# 9      Houston, TX
# 10     Houston, TX
# 11     Houston, TX
# 12     Houston, TX
# 13     Houston, TX
# 14   Arlington, TX
# 15   Arlington, TX
# 16   Arlington, TX
# 17     Houston, TX
# 18     Houston, TX
# 19     Houston, TX
# 20     Seattle, WA
# 21     Seattle, WA
# 22     Seattle, WA
# 23     Oakland, CA
# 24     Oakland, CA
# 25     Oakland, CA
# 26     Houston, TX
# 27     Houston, TX
# 28     Houston, TX
# 29     Houston, TX
# ..             ...
# 134    Houston, TX
# 135  Arlington, TX
# 136  Arlington, TX
# 137  Arlington, TX
# 138  Cleveland, OH
# 139  Cleveland, OH
# 140  Cleveland, OH
# 141  Cleveland, OH
# 142    Houston, TX
# 143    Houston, TX
# 144    Houston, TX
# 145    Houston, TX
# 146    Houston, TX
# 147    Houston, TX
# 148    Seattle, WA
# 149    Seattle, WA
# 150    Seattle, WA
# 151    Oakland, CA
# 152    Oakland, CA
# 153    Oakland, CA
# 154    Houston, TX
# 155    Houston, TX
# 156    Houston, TX
# 157    Houston, TX
# 158    Houston, TX
# 159    Houston, TX
# 160    Houston, TX
# 161    Anaheim, CA
# 162    Anaheim, CA
# 163    Anaheim, CA
#
# [164 rows x 4 columns]
